# %% [markdown]
# <a href="https://colab.research.google.com/github/naghmeadibi/CHW03_MachineLearning/blob/main/HW_NN_Q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align=center>
#
# <font size=5>
#     In the Name of God
# <font/>
# <br/>
# <br/>
# <font>
#     Sharif University of Technology - Departmenet of Electrical Engineering
# </font>
# <br/>
# <font>
#     Introducing with Machine Learing - Dr. S. Amini
# </font>
# <br/>
# <br/>
# Spring 2023
#
# </div>
#
# <hr/>
# <div align=center>
# <font size=6>
#     Neural Networks Practical Assignment
#
#     Question 1
# </font>
# <br/>
# <font size=4>
# <br/>
# </div>

# %% [markdown]
# # Personal Data

# %%
# Set your student number
student_number = 99101076 
Name = 'Naghmeh'
Last_Name = 'Adibi'

# %% [markdown]
# # Rules
# - You are not allowed to add or remove cells. You **must use the provided space to write your code**. If you don't follow this rule, **your Practical Assignment won't be graded**.
#
# - Collaboration and using the internet is allowed, but your code **must be written by yourself**. **Copying code** from each other or from available resources will result in a **zero score for the assignment**.
#
# - You are not allowed to use `torch.nn`, `torch.optim` and any activation function and loss function implemented in torch.

# %%
# !pip install numpy
# !pip install matplotlib
# !pip install torchvision
# !pip install torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.22.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.15.2+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.27.1)
# Requirement already satisfied: torch==2.0.1 in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.0.1+cu118)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (8.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1->torchvision) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1->torchvision) (16.0.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.0.1->torchvision) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.0.1->torchvision) (1.3.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %% [markdown]
# ## Importing Libraries

# %%
import torch
from torchvision.datasets import FashionMNIST
from torchvision import transforms
from torch.utils.data import DataLoader

import numpy as np
from matplotlib import pyplot as plt
from typing import Dict
import random

# %% [markdown]
# ## Datasets and Dataloaders
#
# Here, we download and load the train and test `FashionMNIST` dataset with the desired transforms. Then, we define the dataloaders for `train` and `test`.

# %%
train_set = FashionMNIST(root='.', train=True, download=True, transform=transforms.ToTensor())
test_set = FashionMNIST(root='.', train=False, download=True, transform=transforms.ToTensor())
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:00<00:00, 108884986.37it/s]
# Extracting ./FashionMNIST/raw/train-images-idx3-ubyte.gz to ./FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 6444629.21it/s]
# Extracting ./FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:00<00:00, 64042401.49it/s]
# Extracting ./FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<00:00, 27789288.28it/s]
# Extracting ./FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./FashionMNIST/raw

# %%
image_shape = train_set[0][0].shape
input_dim = np.prod(image_shape).item()
num_classes = len(FashionMNIST.classes)

# %%
train_loader = DataLoader(train_set, 64, shuffle=True)
test_loader = DataLoader(test_set, 64, shuffle=True)

# %% [markdown]
# ## Visualization
#
# Visualize 1 random image from each class
#
# - **Hint**:  You can use `plt.subplots` for visualization

# %%
## FILL HERE
class_images = {}
for i in range(len(train_set)):
    image, label = train_set[i]
    if label not in class_images:
        class_images[label] = image
    elif random.randint(0, 100) == 1:
        class_images[label] = image

print(len(class_images))

fig, axs = plt.subplots(2, 5, figsize=(10, 4))
axs = axs.flatten()
for i in range(num_classes):
    axs[i].imshow(class_images[i][0])
    axs[i].set_title(FashionMNIST.classes[i])
    axs[i].axis('off')
plt.show()
# Out:
# 10

# %% [markdown]
# ## Initializing model's parameters
#
# In this part, we create the model and initialize its parameters and store the values of these parameters in the variable `parameters` which is a dictionary including the weigths and biases of each layer.

# %%
def add_linear_layer(parameters: dict, shape, device, i=None):
    """
    This function adds parameters of a linear unit of shape `shape` to the `parameters` dictionary.
    """
    n_in, n_out = shape
    with torch.no_grad():
        w = torch.zeros(*shape, device=device)
        # kaiming initialization for ReLU activations:
        bound = 1 / np.sqrt(n_in).item()
        w.uniform_(-bound, bound)
        b = torch.zeros(n_out, device=device)  # no need to (1, n_out). it will broadcast itself.
    w.requires_grad = True
    b.requires_grad = True
    # `i` is used to give numbers to parameter names
    parameters.update({f'w{i}': w, f'b{i}': b})

# %% [markdown]
# Now we define our neural network with the given layers and add the weights and biases to the dictionary `parameters`. **You are allowed to modify the values of the layers**.

# %%
layers = [
    (input_dim, 512),
    (512, 256),
    (256, 128),
    (128, 64),
    (64, num_classes)
]
num_layers = len(layers)
parameters = {}

# setting the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# adding the parameters to the dictionary
for i, shape in enumerate(layers):
    add_linear_layer(parameters, shape, device, i)

parameters.keys()
# Out:
# dict_keys(['w0', 'b0', 'w1', 'b1', 'w2', 'b2', 'w3', 'b3', 'w4', 'b4'])

# %% [markdown]
# ## Defining the required functions
#
# In this section, we should define the required functions. For each of these functions, the inputs and the desired outputs are given and you should write all or part of the function. **You are not allowed to use the activation functions and the loss functions implemented in torch**.

# %% [markdown]
# Computing affine and relu outputs:

# %%
def affine_forward(x, w, b):
    ## FILL HERE
    out = torch.matmul(x, w) + b
    cache = (x, w, b)
    return out, cache


def relu(x):
    ## FILL HERE
    out = torch.max(torch.zeros_like(x), x)
    return out

# %% [markdown]
# Function `model` returns output of the whole model for the input `x` using the parameters:

# %%
def model(x: torch.Tensor, parameters, num_layers=num_layers):
    # number of batches
    B = x.shape[0]
    x = x.view(B, -1)
    
    ## FILL HERE
    # forward pass
    for i in range(num_layers):
      w = parameters[f'w{i}']
      b = parameters[f'b{i}']
      out, cache = affine_forward(x, w, b)
      if i < num_layers - 1:
        x = relu(out)
    
    return out

# %% [markdown]
# Implementing cross entropy loss:

# %%
def cross_entropy_loss(scores, y):
    n = len(y)
    ## FILL HERE
    exp_scores = torch.exp(scores)
    probs = exp_scores / torch.sum(exp_scores, dim=1, keepdims=True)
    log_probs = -torch.log(probs[range(n),y])
    loss = torch.sum(log_probs) / n
    return loss

# %% [markdown]
# Implementing a function for optimizing paramters and a function to zeroing out their gradients:

# %%
def sgd_optimizer(parameters: Dict[str, torch.Tensor], learning_rate=0.001):
    '''This function gets the parameters and a learning rate. Then updates the parameters using their
    gradient (parameter.grad). Finally, you should zero the gradients of the parameters after updating
    the parameter value.'''
    ## FILL HERE
    for param in parameters.values():
      param.data -= learning_rate*param.grad
      param.grad.zero_()

# %% [markdown]
# *italicized text*. Training functions:

# %%
def accuracy(y_pred: np.ndarray, y_true: np.ndarray):
    ## FILL HERE
    acc = (y_pred == y_true).mean() 
    return acc

def train(train_loader, learning_rate=0.001, epoch=None):
    '''This function implements the training loop for a single epoch. For each batch you should do the following:
        1- Calculate the output of the model to the given input batch
        2- Calculate the loss based on the model output
        3- Update the gradients using loss.backward() method
        4- Optimize the model parameters using the sgd_optimizer function defined previously
        5- Print the train loss (Show the epoch and batch as well)
        '''
    train_loss = 0
    N_train = len(train_loader.dataset)
    
    # Creating empty lists Y and Y_pred to store the labels and predictions of each batch
    # for calculateing the accuracy later
    Y = []
    Y_pred = []
    
    
    for i, (x, y) in enumerate(train_loader):
        x = x.to(device)
        y = y.to(device)
        p = model(x, parameters)

        ## FILL HERE
        loss = cross_entropy_loss(p, y)
        loss.backward()
        sgd_optimizer(parameters, learning_rate)
        train_loss += loss.item()
        if (i+1) % 100 == 0:
          print(f'Epoch[{epoch}], Batch[{i+1}/{N_train}], Loss:{loss.item()}')
        y_pred = p.argmax(dim=-1)
        Y.append(y.cpu().numpy())
        Y_pred.append(y_pred.cpu().numpy())

    Y = np.concatenate(Y)
    Y_pred = np.concatenate(Y_pred)
    acc = accuracy(Y_pred, Y)
    print(f'Accuracy of train set: {acc}')
    return train_loss/N_train, acc


def validate(loader, epoch=None, set_name=None):
    '''This function validates the model on the test dataloader. The function goes through each batch and does
    the following on each batch:
        1- Calculate the model output
        2- Calculate the loss using the model output
        3- Print the loss for each batch and epoch
    
    Finally the function calculates the model accuracy.'''
    total_loss = 0
    N = len(loader.dataset)
    
    # Creating empty lists Y and Y_pred to store the labels and predictions of each batch
    # for calculateing the accuracy later
    Y = []
    Y_pred = []
    for i, (x, y) in enumerate(loader):
        x = x.to(device)
        y = y.to(device)
        p = model(x, parameters)

        ## FILL HERE
        loss = cross_entropy_loss(p, y)
        total_loss += loss.item()
        print(f"Epoch{epoch}, Batch{i}: Loss={loss.item():.4f}")
        
        y_pred = p.argmax(dim=-1)
        Y.append(y.cpu().numpy())
        Y_pred.append(y_pred.cpu().numpy())
    Y = np.concatenate(Y)
    Y_pred = np.concatenate(Y_pred)
    total_loss /= N
    acc = accuracy(Y_pred, Y)
    print(f'Accuracy of {set_name} set: {acc}')

    return total_loss, acc

# %%
train_losses = []
test_losses = []
train_accuracies = []
test_accuracies = []

# %%
def train_model(dataloaders, num_epochs, learning_rate=0.001, model_name='pytorch_model'):
    '''This function trains the model for the number of epochs given and stores, calculates and prints the train
    and test losses and accuracies. Finally, it plots the accuracy and loss history for training and test sets'''
    train_loader, test_loader = dataloaders

    for epoch in range(num_epochs):
        ## FILL HERE
        ## You should calculate the train and test loss and accuracies for each epoch and add them to
        ## the lists `train_losses`, `test_losses`, `train_accuracies` and `test_accuracies`
        train_loss, train_accuracy = train(train_loader= train_loader, learning_rate=learning_rate, epoch=epoch)
        test_loss, test_accuracy = validate(loader= test_loader, epoch=epoch, set_name=model_name)
        train_losses.append(train_loss)
        test_losses.append(test_loss)
        train_accuracies.append(train_accuracy)
        test_accuracies.append(test_accuracy)


    ## plot the loss history of training and test sets 
    ## FILL HERE
    plt.plot(train_losses, label='Train')
    plt.plot(test_losses, label='Test')
    plt.title('Loss History')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

    ## plot the accuracy history of training and test sets
    ## FILL HERE
    plt.plot(train_accuracies, label='Train')
    plt.plot(test_accuracies, label='Test')
    plt.title('Accuracy History')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

# %%
train_model([train_loader, test_loader], num_epochs=25, learning_rate=0.005)
# Out:
# Epoch[0], Batch[100/60000], Loss:2.299006223678589
# Epoch[0], Batch[200/60000], Loss:2.2985618114471436
# Epoch[0], Batch[300/60000], Loss:2.293820381164551
# Epoch[0], Batch[400/60000], Loss:2.2930874824523926
# Epoch[0], Batch[500/60000], Loss:2.2891359329223633
# Epoch[0], Batch[600/60000], Loss:2.2826850414276123
# Epoch[0], Batch[700/60000], Loss:2.278663158416748
# Epoch[0], Batch[800/60000], Loss:2.2737174034118652
# Epoch[0], Batch[900/60000], Loss:2.2637405395507812
# Accuracy of train set: 0.2863833333333333
# Epoch0, Batch0: Loss=2.2566
# Epoch0, Batch1: Loss=2.2589
# Epoch0, Batch2: Loss=2.2594
# Epoch0, Batch3: Loss=2.2621
# Epoch0, Batch4: Loss=2.2563
# Epoch0, Batch5: Loss=2.2563
# Epoch0, Batch6: Loss=2.2542
# Epoch0, Batch7: Loss=2.2607
# Epoch0, Batch8: Loss=2.2576
# Epoch0, Batch9: Loss=2.2527
# Epoch0, Batch10: Loss=2.2627
# Epoch0, Batch11: Loss=2.2595
# Epoch0, Batch12: Loss=2.2574
# Epoch0, Batch13: Loss=2.2634
# Epoch0, Batch14: Loss=2.2641
# Epoch0, Batch15: Loss=2.2602
# Epoch0, Batch16: Loss=2.2645
# Epoch0, Batch17: Loss=2.2570
# Epoch0, Batch18: Loss=2.2644
# Epoch0, Batch19: Loss=2.2557
# Epoch0, Batch20: Loss=2.2575
# Epoch0, Batch21: Loss=2.2619
# Epoch0, Batch22: Loss=2.2605
# Epoch0, Batch23: Loss=2.2661
# Epoch0, Batch24: Loss=2.2614
# Epoch0, Batch25: Loss=2.2572
# Epoch0, Batch26: Loss=2.2613
# Epoch0, Batch27: Loss=2.2652
# Epoch0, Batch28: Loss=2.2601
# Epoch0, Batch29: Loss=2.2597
# Epoch0, Batch30: Loss=2.2600
# Epoch0, Batch31: Loss=2.2602
# Epoch0, Batch32: Loss=2.2575
# Epoch0, Batch33: Loss=2.2620
# Epoch0, Batch34: Loss=2.2591
# Epoch0, Batch35: Loss=2.2581
# Epoch0, Batch36: Loss=2.2624
# Epoch0, Batch37: Loss=2.2649
# Epoch0, Batch38: Loss=2.2614
# Epoch0, Batch39: Loss=2.2608
# Epoch0, Batch40: Loss=2.2619
# Epoch0, Batch41: Loss=2.2556
# Epoch0, Batch42: Loss=2.2604
# Epoch0, Batch43: Loss=2.2562
# Epoch0, Batch44: Loss=2.2589
# Epoch0, Batch45: Loss=2.2619
# Epoch0, Batch46: Loss=2.2574
# Epoch0, Batch47: Loss=2.2562
# Epoch0, Batch48: Loss=2.2552
# Epoch0, Batch49: Loss=2.2572
# Epoch0, Batch50: Loss=2.2612
# Epoch0, Batch51: Loss=2.2621
# Epoch0, Batch52: Loss=2.2625
# Epoch0, Batch53: Loss=2.2599
# Epoch0, Batch54: Loss=2.2567
# Epoch0, Batch55: Loss=2.2613
# Epoch0, Batch56: Loss=2.2620
# Epoch0, Batch57: Loss=2.2573
# Epoch0, Batch58: Loss=2.2592
# Epoch0, Batch59: Loss=2.2539
# Epoch0, Batch60: Loss=2.2493
# Epoch0, Batch61: Loss=2.2565
# Epoch0, Batch62: Loss=2.2634
# Epoch0, Batch63: Loss=2.2585
# Epoch0, Batch64: Loss=2.2593
# Epoch0, Batch65: Loss=2.2607
# Epoch0, Batch66: Loss=2.2597
# Epoch0, Batch67: Loss=2.2625
# Epoch0, Batch68: Loss=2.2594
# Epoch0, Batch69: Loss=2.2600
# Epoch0, Batch70: Loss=2.2523
# Epoch0, Batch71: Loss=2.2611
# Epoch0, Batch72: Loss=2.2609
# Epoch0, Batch73: Loss=2.2600
# Epoch0, Batch74: Loss=2.2610
# Epoch0, Batch75: Loss=2.2598
# Epoch0, Batch76: Loss=2.2539
# Epoch0, Batch77: Loss=2.2584
# Epoch0, Batch78: Loss=2.2611
# Epoch0, Batch79: Loss=2.2556
# Epoch0, Batch80: Loss=2.2663
# Epoch0, Batch81: Loss=2.2601
# Epoch0, Batch82: Loss=2.2661
# Epoch0, Batch83: Loss=2.2561
# Epoch0, Batch84: Loss=2.2612
# Epoch0, Batch85: Loss=2.2597
# Epoch0, Batch86: Loss=2.2600
# Epoch0, Batch87: Loss=2.2582
# Epoch0, Batch88: Loss=2.2554
# Epoch0, Batch89: Loss=2.2593
# Epoch0, Batch90: Loss=2.2545
# Epoch0, Batch91: Loss=2.2602
# Epoch0, Batch92: Loss=2.2561
# Epoch0, Batch93: Loss=2.2570
# Epoch0, Batch94: Loss=2.2603
# Epoch0, Batch95: Loss=2.2626
# Epoch0, Batch96: Loss=2.2559
# Epoch0, Batch97: Loss=2.2575
# Epoch0, Batch98: Loss=2.2590
# Epoch0, Batch99: Loss=2.2599
# Epoch0, Batch100: Loss=2.2606
# Epoch0, Batch101: Loss=2.2653
# Epoch0, Batch102: Loss=2.2551
# Epoch0, Batch103: Loss=2.2625
# Epoch0, Batch104: Loss=2.2616
# Epoch0, Batch105: Loss=2.2598
# Epoch0, Batch106: Loss=2.2552
# Epoch0, Batch107: Loss=2.2610
# Epoch0, Batch108: Loss=2.2589
# Epoch0, Batch109: Loss=2.2628
# Epoch0, Batch110: Loss=2.2536
# Epoch0, Batch111: Loss=2.2601
# Epoch0, Batch112: Loss=2.2590
# Epoch0, Batch113: Loss=2.2558
# Epoch0, Batch114: Loss=2.2667
# Epoch0, Batch115: Loss=2.2666
# Epoch0, Batch116: Loss=2.2534
# Epoch0, Batch117: Loss=2.2615
# Epoch0, Batch118: Loss=2.2658
# Epoch0, Batch119: Loss=2.2620
# Epoch0, Batch120: Loss=2.2575
# Epoch0, Batch121: Loss=2.2588
# Epoch0, Batch122: Loss=2.2617
# Epoch0, Batch123: Loss=2.2613
# Epoch0, Batch124: Loss=2.2616
# Epoch0, Batch125: Loss=2.2529
# Epoch0, Batch126: Loss=2.2581
# Epoch0, Batch127: Loss=2.2517
# Epoch0, Batch128: Loss=2.2598
# Epoch0, Batch129: Loss=2.2637
# Epoch0, Batch130: Loss=2.2594
# Epoch0, Batch131: Loss=2.2661
# Epoch0, Batch132: Loss=2.2558
# Epoch0, Batch133: Loss=2.2575
# Epoch0, Batch134: Loss=2.2604
# Epoch0, Batch135: Loss=2.2576
# Epoch0, Batch136: Loss=2.2592
# Epoch0, Batch137: Loss=2.2551
# Epoch0, Batch138: Loss=2.2594
# Epoch0, Batch139: Loss=2.2679
# Epoch0, Batch140: Loss=2.2580
# Epoch0, Batch141: Loss=2.2635
# Epoch0, Batch142: Loss=2.2616
# Epoch0, Batch143: Loss=2.2570
# Epoch0, Batch144: Loss=2.2599
# Epoch0, Batch145: Loss=2.2577
# Epoch0, Batch146: Loss=2.2609
# Epoch0, Batch147: Loss=2.2652
# Epoch0, Batch148: Loss=2.2612
# Epoch0, Batch149: Loss=2.2607
# Epoch0, Batch150: Loss=2.2617
# Epoch0, Batch151: Loss=2.2623
# Epoch0, Batch152: Loss=2.2557
# Epoch0, Batch153: Loss=2.2559
# Epoch0, Batch154: Loss=2.2510
# Epoch0, Batch155: Loss=2.2607
# Epoch0, Batch156: Loss=2.2595
# Accuracy of pytorch_model set: 0.2801
# Epoch[1], Batch[100/60000], Loss:2.245868682861328
# Epoch[1], Batch[200/60000], Loss:2.2272262573242188
# Epoch[1], Batch[300/60000], Loss:2.182919502258301
# Epoch[1], Batch[400/60000], Loss:2.142115831375122
# Epoch[1], Batch[500/60000], Loss:2.0661911964416504
# Epoch[1], Batch[600/60000], Loss:1.9168312549591064
# Epoch[1], Batch[700/60000], Loss:1.789276123046875
# Epoch[1], Batch[800/60000], Loss:1.7683948278427124
# Epoch[1], Batch[900/60000], Loss:1.5222229957580566
# Accuracy of train set: 0.2789333333333333
# Epoch1, Batch0: Loss=1.5509
# Epoch1, Batch1: Loss=1.5391
# Epoch1, Batch2: Loss=1.5145
# Epoch1, Batch3: Loss=1.5147
# Epoch1, Batch4: Loss=1.5859
# Epoch1, Batch5: Loss=1.4964
# Epoch1, Batch6: Loss=1.4625
# Epoch1, Batch7: Loss=1.5320
# Epoch1, Batch8: Loss=1.4726
# Epoch1, Batch9: Loss=1.4999
# Epoch1, Batch10: Loss=1.5048
# Epoch1, Batch11: Loss=1.5887
# Epoch1, Batch12: Loss=1.5499
# Epoch1, Batch13: Loss=1.5373
# Epoch1, Batch14: Loss=1.4637
# Epoch1, Batch15: Loss=1.5320
# Epoch1, Batch16: Loss=1.5198
# Epoch1, Batch17: Loss=1.4657
# Epoch1, Batch18: Loss=1.5821
# Epoch1, Batch19: Loss=1.5348
# Epoch1, Batch20: Loss=1.4849
# Epoch1, Batch21: Loss=1.5085
# Epoch1, Batch22: Loss=1.5510
# Epoch1, Batch23: Loss=1.5022
# Epoch1, Batch24: Loss=1.5213
# Epoch1, Batch25: Loss=1.5312
# Epoch1, Batch26: Loss=1.5930
# Epoch1, Batch27: Loss=1.5078
# Epoch1, Batch28: Loss=1.4965
# Epoch1, Batch29: Loss=1.4490
# Epoch1, Batch30: Loss=1.5277
# Epoch1, Batch31: Loss=1.5509
# Epoch1, Batch32: Loss=1.5089
# Epoch1, Batch33: Loss=1.5633
# Epoch1, Batch34: Loss=1.4570
# Epoch1, Batch35: Loss=1.5318
# Epoch1, Batch36: Loss=1.5338
# Epoch1, Batch37: Loss=1.5342
# Epoch1, Batch38: Loss=1.5795
# Epoch1, Batch39: Loss=1.5839
# Epoch1, Batch40: Loss=1.5164
# Epoch1, Batch41: Loss=1.5156
# Epoch1, Batch42: Loss=1.4820
# Epoch1, Batch43: Loss=1.4537
# Epoch1, Batch44: Loss=1.5504
# Epoch1, Batch45: Loss=1.5128
# Epoch1, Batch46: Loss=1.5307
# Epoch1, Batch47: Loss=1.5878
# Epoch1, Batch48: Loss=1.5856
# Epoch1, Batch49: Loss=1.4822
# Epoch1, Batch50: Loss=1.5180
# Epoch1, Batch51: Loss=1.5238
# Epoch1, Batch52: Loss=1.5128
# Epoch1, Batch53: Loss=1.5958
# Epoch1, Batch54: Loss=1.5245
# Epoch1, Batch55: Loss=1.4999
# Epoch1, Batch56: Loss=1.5930
# Epoch1, Batch57: Loss=1.5944
# Epoch1, Batch58: Loss=1.5313
# Epoch1, Batch59: Loss=1.4769
# Epoch1, Batch60: Loss=1.5276
# Epoch1, Batch61: Loss=1.5210
# Epoch1, Batch62: Loss=1.5630
# Epoch1, Batch63: Loss=1.5632
# Epoch1, Batch64: Loss=1.5457
# Epoch1, Batch65: Loss=1.5956
# Epoch1, Batch66: Loss=1.5881
# Epoch1, Batch67: Loss=1.4587
# Epoch1, Batch68: Loss=1.4589
# Epoch1, Batch69: Loss=1.4552
# Epoch1, Batch70: Loss=1.4491
# Epoch1, Batch71: Loss=1.5556
# Epoch1, Batch72: Loss=1.5465
# Epoch1, Batch73: Loss=1.5632
# Epoch1, Batch74: Loss=1.5903
# Epoch1, Batch75: Loss=1.4094
# Epoch1, Batch76: Loss=1.4587
# Epoch1, Batch77: Loss=1.6698
# Epoch1, Batch78: Loss=1.4151
# Epoch1, Batch79: Loss=1.5508
# Epoch1, Batch80: Loss=1.4834
# Epoch1, Batch81: Loss=1.5296
# Epoch1, Batch82: Loss=1.5388
# Epoch1, Batch83: Loss=1.4387
# Epoch1, Batch84: Loss=1.5140
# Epoch1, Batch85: Loss=1.4636
# Epoch1, Batch86: Loss=1.5627
# Epoch1, Batch87: Loss=1.4840
# Epoch1, Batch88: Loss=1.4408
# Epoch1, Batch89: Loss=1.4861
# Epoch1, Batch90: Loss=1.4311
# Epoch1, Batch91: Loss=1.5938
# Epoch1, Batch92: Loss=1.4820
# Epoch1, Batch93: Loss=1.5025
# Epoch1, Batch94: Loss=1.5401
# Epoch1, Batch95: Loss=1.4714
# Epoch1, Batch96: Loss=1.5252
# Epoch1, Batch97: Loss=1.4536
# Epoch1, Batch98: Loss=1.5005
# Epoch1, Batch99: Loss=1.5227
# Epoch1, Batch100: Loss=1.5882
# Epoch1, Batch101: Loss=1.4379
# Epoch1, Batch102: Loss=1.5459
# Epoch1, Batch103: Loss=1.4840
# Epoch1, Batch104: Loss=1.5261
# Epoch1, Batch105: Loss=1.4946
# Epoch1, Batch106: Loss=1.5208
# Epoch1, Batch107: Loss=1.5242
# Epoch1, Batch108: Loss=1.5742
# Epoch1, Batch109: Loss=1.4578
# Epoch1, Batch110: Loss=1.6175
# Epoch1, Batch111: Loss=1.5323
# Epoch1, Batch112: Loss=1.5464
# Epoch1, Batch113: Loss=1.4723
# Epoch1, Batch114: Loss=1.5354
# Epoch1, Batch115: Loss=1.6038
# Epoch1, Batch116: Loss=1.5200
# Epoch1, Batch117: Loss=1.5621
# Epoch1, Batch118: Loss=1.5427
# Epoch1, Batch119: Loss=1.5608
# Epoch1, Batch120: Loss=1.6228
# Epoch1, Batch121: Loss=1.5232
# Epoch1, Batch122: Loss=1.5692
# Epoch1, Batch123: Loss=1.5107
# Epoch1, Batch124: Loss=1.5286
# Epoch1, Batch125: Loss=1.4312
# Epoch1, Batch126: Loss=1.5132
# Epoch1, Batch127: Loss=1.5231
# Epoch1, Batch128: Loss=1.5457
# Epoch1, Batch129: Loss=1.4920
# Epoch1, Batch130: Loss=1.5654
# Epoch1, Batch131: Loss=1.5579
# Epoch1, Batch132: Loss=1.4859
# Epoch1, Batch133: Loss=1.5310
# Epoch1, Batch134: Loss=1.5268
# Epoch1, Batch135: Loss=1.5837
# Epoch1, Batch136: Loss=1.5099
# Epoch1, Batch137: Loss=1.5102
# Epoch1, Batch138: Loss=1.5637
# Epoch1, Batch139: Loss=1.5295
# Epoch1, Batch140: Loss=1.4861
# Epoch1, Batch141: Loss=1.4289
# Epoch1, Batch142: Loss=1.5088
# Epoch1, Batch143: Loss=1.5987
# Epoch1, Batch144: Loss=1.5815
# Epoch1, Batch145: Loss=1.5478
# Epoch1, Batch146: Loss=1.3832
# Epoch1, Batch147: Loss=1.4784
# Epoch1, Batch148: Loss=1.5833
# Epoch1, Batch149: Loss=1.5025
# Epoch1, Batch150: Loss=1.5364
# Epoch1, Batch151: Loss=1.5315
# Epoch1, Batch152: Loss=1.4848
# Epoch1, Batch153: Loss=1.5098
# Epoch1, Batch154: Loss=1.4904
# Epoch1, Batch155: Loss=1.4895
# Epoch1, Batch156: Loss=1.6369
# Accuracy of pytorch_model set: 0.4387
# Epoch[2], Batch[100/60000], Loss:1.4780126810073853
# Epoch[2], Batch[200/60000], Loss:1.3080596923828125
# Epoch[2], Batch[300/60000], Loss:1.2064054012298584
# Epoch[2], Batch[400/60000], Loss:1.3311262130737305
# Epoch[2], Batch[500/60000], Loss:1.139543890953064
# Epoch[2], Batch[600/60000], Loss:1.195103406906128
# Epoch[2], Batch[700/60000], Loss:1.020282506942749
# Epoch[2], Batch[800/60000], Loss:1.0075844526290894
# Epoch[2], Batch[900/60000], Loss:1.1507234573364258
# Accuracy of train set: 0.518
# Epoch2, Batch0: Loss=1.3022
# Epoch2, Batch1: Loss=1.1662
# Epoch2, Batch2: Loss=0.9905
# Epoch2, Batch3: Loss=1.2232
# Epoch2, Batch4: Loss=1.0494
# Epoch2, Batch5: Loss=1.0661
# Epoch2, Batch6: Loss=1.1065
# Epoch2, Batch7: Loss=1.0239
# Epoch2, Batch8: Loss=1.0593
# Epoch2, Batch9: Loss=1.0897
# Epoch2, Batch10: Loss=1.0573
# Epoch2, Batch11: Loss=1.1379
# Epoch2, Batch12: Loss=1.1276
# Epoch2, Batch13: Loss=1.1129
# Epoch2, Batch14: Loss=1.0327
# Epoch2, Batch15: Loss=1.1193
# Epoch2, Batch16: Loss=1.1209
# Epoch2, Batch17: Loss=0.9760
# Epoch2, Batch18: Loss=1.1670
# Epoch2, Batch19: Loss=1.2383
# Epoch2, Batch20: Loss=0.9956
# Epoch2, Batch21: Loss=1.2236
# Epoch2, Batch22: Loss=0.9742
# Epoch2, Batch23: Loss=1.2295
# Epoch2, Batch24: Loss=1.0596
# Epoch2, Batch25: Loss=1.0088
# Epoch2, Batch26: Loss=1.0935
# Epoch2, Batch27: Loss=1.0412
# Epoch2, Batch28: Loss=1.2338
# Epoch2, Batch29: Loss=1.0763
# Epoch2, Batch30: Loss=1.1969
# Epoch2, Batch31: Loss=1.0892
# Epoch2, Batch32: Loss=1.1124
# Epoch2, Batch33: Loss=1.2415
# Epoch2, Batch34: Loss=0.9553
# Epoch2, Batch35: Loss=0.9878
# Epoch2, Batch36: Loss=1.0526
# Epoch2, Batch37: Loss=1.1930
# Epoch2, Batch38: Loss=1.1039
# Epoch2, Batch39: Loss=0.9757
# Epoch2, Batch40: Loss=1.0254
# Epoch2, Batch41: Loss=1.1894
# Epoch2, Batch42: Loss=1.0518
# Epoch2, Batch43: Loss=0.9998
# Epoch2, Batch44: Loss=1.0875
# Epoch2, Batch45: Loss=1.0455
# Epoch2, Batch46: Loss=0.9718
# Epoch2, Batch47: Loss=1.0257
# Epoch2, Batch48: Loss=1.2563
# Epoch2, Batch49: Loss=1.0004
# Epoch2, Batch50: Loss=1.1547
# Epoch2, Batch51: Loss=1.0296
# Epoch2, Batch52: Loss=1.0017
# Epoch2, Batch53: Loss=1.1192
# Epoch2, Batch54: Loss=1.1882
# Epoch2, Batch55: Loss=1.0805
# Epoch2, Batch56: Loss=1.0289
# Epoch2, Batch57: Loss=1.1334
# Epoch2, Batch58: Loss=1.2465
# Epoch2, Batch59: Loss=1.1480
# Epoch2, Batch60: Loss=1.0554
# Epoch2, Batch61: Loss=1.0978
# Epoch2, Batch62: Loss=1.0795
# Epoch2, Batch63: Loss=1.0951
# Epoch2, Batch64: Loss=1.1087
# Epoch2, Batch65: Loss=1.1226
# Epoch2, Batch66: Loss=1.1099
# Epoch2, Batch67: Loss=1.0787
# Epoch2, Batch68: Loss=1.1904
# Epoch2, Batch69: Loss=1.0156
# Epoch2, Batch70: Loss=1.1714
# Epoch2, Batch71: Loss=1.0412
# Epoch2, Batch72: Loss=0.9046
# Epoch2, Batch73: Loss=1.1531
# Epoch2, Batch74: Loss=0.9924
# Epoch2, Batch75: Loss=1.0888
# Epoch2, Batch76: Loss=1.0024
# Epoch2, Batch77: Loss=1.0171
# Epoch2, Batch78: Loss=1.0501
# Epoch2, Batch79: Loss=1.0498
# Epoch2, Batch80: Loss=0.9965
# Epoch2, Batch81: Loss=1.0792
# Epoch2, Batch82: Loss=1.0323
# Epoch2, Batch83: Loss=0.9262
# Epoch2, Batch84: Loss=1.0176
# Epoch2, Batch85: Loss=1.1942
# Epoch2, Batch86: Loss=1.1132
# Epoch2, Batch87: Loss=1.0309
# Epoch2, Batch88: Loss=1.1882
# Epoch2, Batch89: Loss=1.1174
# Epoch2, Batch90: Loss=0.9319
# Epoch2, Batch91: Loss=0.9331
# Epoch2, Batch92: Loss=0.9496
# Epoch2, Batch93: Loss=1.1591
# Epoch2, Batch94: Loss=1.1886
# Epoch2, Batch95: Loss=1.1116
# Epoch2, Batch96: Loss=1.0317
# Epoch2, Batch97: Loss=1.0817
# Epoch2, Batch98: Loss=0.9701
# Epoch2, Batch99: Loss=1.1629
# Epoch2, Batch100: Loss=1.1688
# Epoch2, Batch101: Loss=0.9384
# Epoch2, Batch102: Loss=1.0028
# Epoch2, Batch103: Loss=1.1918
# Epoch2, Batch104: Loss=1.0741
# Epoch2, Batch105: Loss=1.0419
# Epoch2, Batch106: Loss=1.0846
# Epoch2, Batch107: Loss=1.1760
# Epoch2, Batch108: Loss=1.1435
# Epoch2, Batch109: Loss=1.0585
# Epoch2, Batch110: Loss=1.0604
# Epoch2, Batch111: Loss=0.9442
# Epoch2, Batch112: Loss=1.0373
# Epoch2, Batch113: Loss=1.0984
# Epoch2, Batch114: Loss=1.0514
# Epoch2, Batch115: Loss=1.1524
# Epoch2, Batch116: Loss=1.0632
# Epoch2, Batch117: Loss=1.1170
# Epoch2, Batch118: Loss=1.1502
# Epoch2, Batch119: Loss=1.1840
# Epoch2, Batch120: Loss=0.9768
# Epoch2, Batch121: Loss=1.0537
# Epoch2, Batch122: Loss=1.0572
# Epoch2, Batch123: Loss=0.9736
# Epoch2, Batch124: Loss=1.1527
# Epoch2, Batch125: Loss=1.2621
# Epoch2, Batch126: Loss=0.9888
# Epoch2, Batch127: Loss=1.0891
# Epoch2, Batch128: Loss=1.0512
# Epoch2, Batch129: Loss=1.1857
# Epoch2, Batch130: Loss=1.1854
# Epoch2, Batch131: Loss=1.0406
# Epoch2, Batch132: Loss=0.8961
# Epoch2, Batch133: Loss=0.9746
# Epoch2, Batch134: Loss=0.9953
# Epoch2, Batch135: Loss=1.0814
# Epoch2, Batch136: Loss=1.1015
# Epoch2, Batch137: Loss=1.1576
# Epoch2, Batch138: Loss=1.0691
# Epoch2, Batch139: Loss=0.9658
# Epoch2, Batch140: Loss=1.0860
# Epoch2, Batch141: Loss=0.9727
# Epoch2, Batch142: Loss=1.0482
# Epoch2, Batch143: Loss=1.0323
# Epoch2, Batch144: Loss=1.0168
# Epoch2, Batch145: Loss=1.0347
# Epoch2, Batch146: Loss=0.9264
# Epoch2, Batch147: Loss=0.9853
# Epoch2, Batch148: Loss=0.9307
# Epoch2, Batch149: Loss=0.9867
# Epoch2, Batch150: Loss=1.0380
# Epoch2, Batch151: Loss=1.1234
# Epoch2, Batch152: Loss=0.9831
# Epoch2, Batch153: Loss=1.0021
# Epoch2, Batch154: Loss=1.1275
# Epoch2, Batch155: Loss=0.9710
# Epoch2, Batch156: Loss=0.8992
# Accuracy of pytorch_model set: 0.55
# Epoch[3], Batch[100/60000], Loss:1.0243350267410278
# Epoch[3], Batch[200/60000], Loss:0.9779535531997681
# Epoch[3], Batch[300/60000], Loss:0.9943972229957581
# Epoch[3], Batch[400/60000], Loss:1.1838277578353882
# Epoch[3], Batch[500/60000], Loss:0.9693431258201599
# Epoch[3], Batch[600/60000], Loss:1.040001630783081
# Epoch[3], Batch[700/60000], Loss:1.1429411172866821
# Epoch[3], Batch[800/60000], Loss:0.9072104096412659
# Epoch[3], Batch[900/60000], Loss:0.976006269454956
# Accuracy of train set: 0.6295
# Epoch3, Batch0: Loss=0.7366
# Epoch3, Batch1: Loss=0.9169
# Epoch3, Batch2: Loss=0.8171
# Epoch3, Batch3: Loss=0.9262
# Epoch3, Batch4: Loss=0.9330
# Epoch3, Batch5: Loss=0.6618
# Epoch3, Batch6: Loss=0.9636
# Epoch3, Batch7: Loss=0.9229
# Epoch3, Batch8: Loss=0.8143
# Epoch3, Batch9: Loss=0.7612
# Epoch3, Batch10: Loss=0.7432
# Epoch3, Batch11: Loss=0.8060
# Epoch3, Batch12: Loss=0.9018
# Epoch3, Batch13: Loss=0.9763
# Epoch3, Batch14: Loss=0.8664
# Epoch3, Batch15: Loss=0.6342
# Epoch3, Batch16: Loss=0.9586
# Epoch3, Batch17: Loss=0.8939
# Epoch3, Batch18: Loss=0.7934
# Epoch3, Batch19: Loss=0.8604
# Epoch3, Batch20: Loss=0.8755
# Epoch3, Batch21: Loss=0.9315
# Epoch3, Batch22: Loss=0.7848
# Epoch3, Batch23: Loss=0.7730
# Epoch3, Batch24: Loss=0.6669
# Epoch3, Batch25: Loss=0.8731
# Epoch3, Batch26: Loss=1.1296
# Epoch3, Batch27: Loss=0.8951
# Epoch3, Batch28: Loss=0.7473
# Epoch3, Batch29: Loss=0.6664
# Epoch3, Batch30: Loss=0.7003
# Epoch3, Batch31: Loss=0.7498
# Epoch3, Batch32: Loss=0.9991
# Epoch3, Batch33: Loss=1.3053
# Epoch3, Batch34: Loss=0.8046
# Epoch3, Batch35: Loss=1.0675
# Epoch3, Batch36: Loss=1.0380
# Epoch3, Batch37: Loss=1.0442
# Epoch3, Batch38: Loss=0.7551
# Epoch3, Batch39: Loss=1.0050
# Epoch3, Batch40: Loss=0.7697
# Epoch3, Batch41: Loss=0.9745
# Epoch3, Batch42: Loss=0.9610
# Epoch3, Batch43: Loss=0.8821
# Epoch3, Batch44: Loss=0.8010
# Epoch3, Batch45: Loss=0.9975
# Epoch3, Batch46: Loss=0.9125
# Epoch3, Batch47: Loss=0.8736
# Epoch3, Batch48: Loss=0.8239
# Epoch3, Batch49: Loss=0.8295
# Epoch3, Batch50: Loss=0.7314
# Epoch3, Batch51: Loss=0.8270
# Epoch3, Batch52: Loss=0.8809
# Epoch3, Batch53: Loss=0.7834
# Epoch3, Batch54: Loss=0.8275
# Epoch3, Batch55: Loss=0.9775
# Epoch3, Batch56: Loss=0.9352
# Epoch3, Batch57: Loss=0.9575
# Epoch3, Batch58: Loss=0.8603
# Epoch3, Batch59: Loss=0.9661
# Epoch3, Batch60: Loss=1.0179
# Epoch3, Batch61: Loss=0.9046
# Epoch3, Batch62: Loss=0.8289
# Epoch3, Batch63: Loss=1.0712
# Epoch3, Batch64: Loss=0.6967
# Epoch3, Batch65: Loss=0.8801
# Epoch3, Batch66: Loss=0.8268
# Epoch3, Batch67: Loss=0.8867
# Epoch3, Batch68: Loss=0.8645
# Epoch3, Batch69: Loss=0.8385
# Epoch3, Batch70: Loss=0.9186
# Epoch3, Batch71: Loss=0.8331
# Epoch3, Batch72: Loss=0.8434
# Epoch3, Batch73: Loss=0.7484
# Epoch3, Batch74: Loss=0.7887
# Epoch3, Batch75: Loss=0.9143
# Epoch3, Batch76: Loss=0.8143
# Epoch3, Batch77: Loss=0.9724
# Epoch3, Batch78: Loss=0.8612
# Epoch3, Batch79: Loss=0.6367
# Epoch3, Batch80: Loss=0.8115
# Epoch3, Batch81: Loss=0.9177
# Epoch3, Batch82: Loss=0.8790
# Epoch3, Batch83: Loss=0.7646
# Epoch3, Batch84: Loss=1.0222
# Epoch3, Batch85: Loss=0.9199
# Epoch3, Batch86: Loss=0.8219
# Epoch3, Batch87: Loss=0.8220
# Epoch3, Batch88: Loss=1.0051
# Epoch3, Batch89: Loss=0.8043
# Epoch3, Batch90: Loss=0.7991
# Epoch3, Batch91: Loss=1.1332
# Epoch3, Batch92: Loss=0.9668
# Epoch3, Batch93: Loss=1.0251
# Epoch3, Batch94: Loss=0.7627
# Epoch3, Batch95: Loss=0.8572
# Epoch3, Batch96: Loss=0.6779
# Epoch3, Batch97: Loss=0.8246
# Epoch3, Batch98: Loss=0.8738
# Epoch3, Batch99: Loss=0.8571
# Epoch3, Batch100: Loss=0.6222
# Epoch3, Batch101: Loss=0.6546
# Epoch3, Batch102: Loss=0.9344
# Epoch3, Batch103: Loss=1.0069
# Epoch3, Batch104: Loss=0.9517
# Epoch3, Batch105: Loss=0.8611
# Epoch3, Batch106: Loss=0.7804
# Epoch3, Batch107: Loss=1.2133
# Epoch3, Batch108: Loss=0.7132
# Epoch3, Batch109: Loss=1.0315
# Epoch3, Batch110: Loss=0.8882
# Epoch3, Batch111: Loss=1.0191
# Epoch3, Batch112: Loss=0.7926
# Epoch3, Batch113: Loss=1.0057
# Epoch3, Batch114: Loss=0.8662
# Epoch3, Batch115: Loss=0.7277
# Epoch3, Batch116: Loss=0.7820
# Epoch3, Batch117: Loss=0.7508
# Epoch3, Batch118: Loss=0.8172
# Epoch3, Batch119: Loss=1.0335
# Epoch3, Batch120: Loss=0.8338
# Epoch3, Batch121: Loss=0.7899
# Epoch3, Batch122: Loss=1.0964
# Epoch3, Batch123: Loss=0.9334
# Epoch3, Batch124: Loss=0.8530
# Epoch3, Batch125: Loss=0.8945
# Epoch3, Batch126: Loss=0.8860
# Epoch3, Batch127: Loss=0.7740
# Epoch3, Batch128: Loss=0.8832
# Epoch3, Batch129: Loss=1.0213
# Epoch3, Batch130: Loss=0.9060
# Epoch3, Batch131: Loss=0.8016
# Epoch3, Batch132: Loss=0.9578
# Epoch3, Batch133: Loss=0.8557
# Epoch3, Batch134: Loss=0.8825
# Epoch3, Batch135: Loss=0.6397
# Epoch3, Batch136: Loss=0.7680
# Epoch3, Batch137: Loss=0.8805
# Epoch3, Batch138: Loss=0.8319
# Epoch3, Batch139: Loss=0.9088
# Epoch3, Batch140: Loss=1.1404
# Epoch3, Batch141: Loss=0.9136
# Epoch3, Batch142: Loss=0.9243
# Epoch3, Batch143: Loss=0.8940
# Epoch3, Batch144: Loss=0.7684
# Epoch3, Batch145: Loss=0.8466
# Epoch3, Batch146: Loss=0.8823
# Epoch3, Batch147: Loss=0.9049
# Epoch3, Batch148: Loss=0.9116
# Epoch3, Batch149: Loss=0.8327
# Epoch3, Batch150: Loss=0.7770
# Epoch3, Batch151: Loss=0.9154
# Epoch3, Batch152: Loss=0.8944
# Epoch3, Batch153: Loss=0.7368
# Epoch3, Batch154: Loss=0.9013
# Epoch3, Batch155: Loss=1.0280
# Epoch3, Batch156: Loss=0.7305
# Accuracy of pytorch_model set: 0.6673
# Epoch[4], Batch[100/60000], Loss:0.8770163059234619
# Epoch[4], Batch[200/60000], Loss:0.7718573212623596
# Epoch[4], Batch[300/60000], Loss:0.7986360192298889
# Epoch[4], Batch[400/60000], Loss:1.0381641387939453
# Epoch[4], Batch[500/60000], Loss:0.7231483459472656
# Epoch[4], Batch[600/60000], Loss:0.7241586446762085
# Epoch[4], Batch[700/60000], Loss:0.8501193523406982
# Epoch[4], Batch[800/60000], Loss:0.7549065947532654
# Epoch[4], Batch[900/60000], Loss:0.6383768320083618
# Accuracy of train set: 0.6856833333333333
# Epoch4, Batch0: Loss=0.7534
# Epoch4, Batch1: Loss=0.8961
# Epoch4, Batch2: Loss=0.9523
# Epoch4, Batch3: Loss=0.7661
# Epoch4, Batch4: Loss=0.8396
# Epoch4, Batch5: Loss=0.8776
# Epoch4, Batch6: Loss=0.9155
# Epoch4, Batch7: Loss=0.5777
# Epoch4, Batch8: Loss=0.9592
# Epoch4, Batch9: Loss=1.0014
# Epoch4, Batch10: Loss=0.7263
# Epoch4, Batch11: Loss=0.6770
# Epoch4, Batch12: Loss=0.8838
# Epoch4, Batch13: Loss=0.8087
# Epoch4, Batch14: Loss=0.6303
# Epoch4, Batch15: Loss=0.9765
# Epoch4, Batch16: Loss=0.8418
# Epoch4, Batch17: Loss=0.8709
# Epoch4, Batch18: Loss=0.8153
# Epoch4, Batch19: Loss=0.7874
# Epoch4, Batch20: Loss=0.8136
# Epoch4, Batch21: Loss=0.6737
# Epoch4, Batch22: Loss=0.8136
# Epoch4, Batch23: Loss=0.8620
# Epoch4, Batch24: Loss=0.8191
# Epoch4, Batch25: Loss=0.9292
# Epoch4, Batch26: Loss=0.8460
# Epoch4, Batch27: Loss=0.7704
# Epoch4, Batch28: Loss=0.8190
# Epoch4, Batch29: Loss=1.0466
# Epoch4, Batch30: Loss=0.8108
# Epoch4, Batch31: Loss=0.6299
# Epoch4, Batch32: Loss=0.7419
# Epoch4, Batch33: Loss=0.7784
# Epoch4, Batch34: Loss=0.9373
# Epoch4, Batch35: Loss=0.6513
# Epoch4, Batch36: Loss=0.9983
# Epoch4, Batch37: Loss=1.0505
# Epoch4, Batch38: Loss=0.7168
# Epoch4, Batch39: Loss=0.7815
# Epoch4, Batch40: Loss=1.0029
# Epoch4, Batch41: Loss=1.0941
# Epoch4, Batch42: Loss=0.6113
# Epoch4, Batch43: Loss=0.7734
# Epoch4, Batch44: Loss=0.7254
# Epoch4, Batch45: Loss=0.8668
# Epoch4, Batch46: Loss=0.9253
# Epoch4, Batch47: Loss=0.8759
# Epoch4, Batch48: Loss=0.8073
# Epoch4, Batch49: Loss=0.6982
# Epoch4, Batch50: Loss=0.6571
# Epoch4, Batch51: Loss=0.8928
# Epoch4, Batch52: Loss=0.7758
# Epoch4, Batch53: Loss=0.6250
# Epoch4, Batch54: Loss=0.6950
# Epoch4, Batch55: Loss=0.9994
# Epoch4, Batch56: Loss=0.8366
# Epoch4, Batch57: Loss=0.6530
# Epoch4, Batch58: Loss=0.8897
# Epoch4, Batch59: Loss=0.8527
# Epoch4, Batch60: Loss=0.8984
# Epoch4, Batch61: Loss=0.8701
# Epoch4, Batch62: Loss=0.7052
# Epoch4, Batch63: Loss=0.7200
# Epoch4, Batch64: Loss=0.9153
# Epoch4, Batch65: Loss=0.8308
# Epoch4, Batch66: Loss=0.7417
# Epoch4, Batch67: Loss=0.6765
# Epoch4, Batch68: Loss=0.9804
# Epoch4, Batch69: Loss=0.6579
# Epoch4, Batch70: Loss=0.9193
# Epoch4, Batch71: Loss=0.7771
# Epoch4, Batch72: Loss=0.8659
# Epoch4, Batch73: Loss=0.7703
# Epoch4, Batch74: Loss=0.7511
# Epoch4, Batch75: Loss=0.7523
# Epoch4, Batch76: Loss=0.6480
# Epoch4, Batch77: Loss=0.8647
# Epoch4, Batch78: Loss=0.7900
# Epoch4, Batch79: Loss=0.8327
# Epoch4, Batch80: Loss=0.9191
# Epoch4, Batch81: Loss=0.8095
# Epoch4, Batch82: Loss=0.6891
# Epoch4, Batch83: Loss=0.8876
# Epoch4, Batch84: Loss=0.8247
# Epoch4, Batch85: Loss=0.8708
# Epoch4, Batch86: Loss=0.6065
# Epoch4, Batch87: Loss=0.8263
# Epoch4, Batch88: Loss=0.9152
# Epoch4, Batch89: Loss=0.6138
# Epoch4, Batch90: Loss=0.9397
# Epoch4, Batch91: Loss=0.8937
# Epoch4, Batch92: Loss=0.7264
# Epoch4, Batch93: Loss=0.7002
# Epoch4, Batch94: Loss=0.9046
# Epoch4, Batch95: Loss=0.7335
# Epoch4, Batch96: Loss=0.8983
# Epoch4, Batch97: Loss=0.8901
# Epoch4, Batch98: Loss=0.8469
# Epoch4, Batch99: Loss=0.9070
# Epoch4, Batch100: Loss=0.7636
# Epoch4, Batch101: Loss=0.8841
# Epoch4, Batch102: Loss=0.7834
# Epoch4, Batch103: Loss=0.5588
# Epoch4, Batch104: Loss=0.7243
# Epoch4, Batch105: Loss=0.9369
# Epoch4, Batch106: Loss=0.7772
# Epoch4, Batch107: Loss=0.9056
# Epoch4, Batch108: Loss=0.8427
# Epoch4, Batch109: Loss=0.8437
# Epoch4, Batch110: Loss=0.9099
# Epoch4, Batch111: Loss=0.8717
# Epoch4, Batch112: Loss=0.6826
# Epoch4, Batch113: Loss=0.9646
# Epoch4, Batch114: Loss=0.8370
# Epoch4, Batch115: Loss=0.6758
# Epoch4, Batch116: Loss=0.8717
# Epoch4, Batch117: Loss=0.7149
# Epoch4, Batch118: Loss=0.9798
# Epoch4, Batch119: Loss=0.9478
# Epoch4, Batch120: Loss=1.0262
# Epoch4, Batch121: Loss=0.7597
# Epoch4, Batch122: Loss=0.7534
# Epoch4, Batch123: Loss=1.0199
# Epoch4, Batch124: Loss=1.0016
# Epoch4, Batch125: Loss=0.9509
# Epoch4, Batch126: Loss=0.6835
# Epoch4, Batch127: Loss=0.7451
# Epoch4, Batch128: Loss=0.7141
# Epoch4, Batch129: Loss=1.0520
# Epoch4, Batch130: Loss=0.7723
# Epoch4, Batch131: Loss=0.9463
# Epoch4, Batch132: Loss=0.7051
# Epoch4, Batch133: Loss=0.8215
# Epoch4, Batch134: Loss=1.0698
# Epoch4, Batch135: Loss=0.8437
# Epoch4, Batch136: Loss=0.7230
# Epoch4, Batch137: Loss=0.9628
# Epoch4, Batch138: Loss=0.7907
# Epoch4, Batch139: Loss=0.9674
# Epoch4, Batch140: Loss=0.6485
# Epoch4, Batch141: Loss=0.6598
# Epoch4, Batch142: Loss=0.8375
# Epoch4, Batch143: Loss=0.8222
# Epoch4, Batch144: Loss=0.7541
# Epoch4, Batch145: Loss=0.6681
# Epoch4, Batch146: Loss=0.9108
# Epoch4, Batch147: Loss=0.7501
# Epoch4, Batch148: Loss=0.8589
# Epoch4, Batch149: Loss=0.8263
# Epoch4, Batch150: Loss=0.7828
# Epoch4, Batch151: Loss=1.0132
# Epoch4, Batch152: Loss=0.7778
# Epoch4, Batch153: Loss=0.9438
# Epoch4, Batch154: Loss=0.8562
# Epoch4, Batch155: Loss=0.8447
# Epoch4, Batch156: Loss=0.7449
# Accuracy of pytorch_model set: 0.686
# Epoch[5], Batch[100/60000], Loss:0.6864020228385925
# Epoch[5], Batch[200/60000], Loss:0.8173341751098633
# Epoch[5], Batch[300/60000], Loss:0.7371528744697571
# Epoch[5], Batch[400/60000], Loss:0.5802091360092163
# Epoch[5], Batch[500/60000], Loss:0.6708083152770996
# Epoch[5], Batch[600/60000], Loss:1.0062178373336792
# Epoch[5], Batch[700/60000], Loss:0.6663137078285217
# Epoch[5], Batch[800/60000], Loss:0.6561697125434875
# Epoch[5], Batch[900/60000], Loss:0.7387879490852356
# Accuracy of train set: 0.7156166666666667
# Epoch5, Batch0: Loss=0.7367
# Epoch5, Batch1: Loss=0.6236
# Epoch5, Batch2: Loss=0.7632
# Epoch5, Batch3: Loss=0.6926
# Epoch5, Batch4: Loss=0.9943
# Epoch5, Batch5: Loss=0.7031
# Epoch5, Batch6: Loss=0.7919
# Epoch5, Batch7: Loss=0.8102
# Epoch5, Batch8: Loss=0.7178
# Epoch5, Batch9: Loss=0.9594
# Epoch5, Batch10: Loss=0.6494
# Epoch5, Batch11: Loss=0.7541
# Epoch5, Batch12: Loss=0.7335
# Epoch5, Batch13: Loss=0.8290
# Epoch5, Batch14: Loss=0.7967
# Epoch5, Batch15: Loss=0.8337
# Epoch5, Batch16: Loss=0.8680
# Epoch5, Batch17: Loss=0.6805
# Epoch5, Batch18: Loss=0.5579
# Epoch5, Batch19: Loss=1.0097
# Epoch5, Batch20: Loss=0.6417
# Epoch5, Batch21: Loss=0.7440
# Epoch5, Batch22: Loss=0.7949
# Epoch5, Batch23: Loss=0.5069
# Epoch5, Batch24: Loss=0.6586
# Epoch5, Batch25: Loss=0.8676
# Epoch5, Batch26: Loss=0.7936
# Epoch5, Batch27: Loss=0.7870
# Epoch5, Batch28: Loss=0.6743
# Epoch5, Batch29: Loss=1.0224
# Epoch5, Batch30: Loss=0.7157
# Epoch5, Batch31: Loss=0.6059
# Epoch5, Batch32: Loss=0.9185
# Epoch5, Batch33: Loss=0.8179
# Epoch5, Batch34: Loss=0.6423
# Epoch5, Batch35: Loss=1.0698
# Epoch5, Batch36: Loss=0.6719
# Epoch5, Batch37: Loss=0.5738
# Epoch5, Batch38: Loss=0.5771
# Epoch5, Batch39: Loss=0.7582
# Epoch5, Batch40: Loss=1.0644
# Epoch5, Batch41: Loss=0.6688
# Epoch5, Batch42: Loss=0.9555
# Epoch5, Batch43: Loss=1.1012
# Epoch5, Batch44: Loss=0.9185
# Epoch5, Batch45: Loss=0.7445
# Epoch5, Batch46: Loss=0.7222
# Epoch5, Batch47: Loss=0.6680
# Epoch5, Batch48: Loss=0.5842
# Epoch5, Batch49: Loss=0.6232
# Epoch5, Batch50: Loss=0.7064
# Epoch5, Batch51: Loss=0.8011
# Epoch5, Batch52: Loss=0.9346
# Epoch5, Batch53: Loss=0.5614
# Epoch5, Batch54: Loss=0.8188
# Epoch5, Batch55: Loss=0.7634
# Epoch5, Batch56: Loss=0.7717
# Epoch5, Batch57: Loss=0.9110
# Epoch5, Batch58: Loss=0.7410
# Epoch5, Batch59: Loss=0.8502
# Epoch5, Batch60: Loss=0.8146
# Epoch5, Batch61: Loss=0.9709
# Epoch5, Batch62: Loss=0.8454
# Epoch5, Batch63: Loss=0.6864
# Epoch5, Batch64: Loss=0.7980
# Epoch5, Batch65: Loss=0.7759
# Epoch5, Batch66: Loss=0.7337
# Epoch5, Batch67: Loss=0.6422
# Epoch5, Batch68: Loss=0.7209
# Epoch5, Batch69: Loss=0.8556
# Epoch5, Batch70: Loss=0.7561
# Epoch5, Batch71: Loss=0.6349
# Epoch5, Batch72: Loss=0.7313
# Epoch5, Batch73: Loss=0.5752
# Epoch5, Batch74: Loss=0.7054
# Epoch5, Batch75: Loss=0.6826
# Epoch5, Batch76: Loss=0.7671
# Epoch5, Batch77: Loss=1.0636
# Epoch5, Batch78: Loss=0.7867
# Epoch5, Batch79: Loss=0.6472
# Epoch5, Batch80: Loss=0.7056
# Epoch5, Batch81: Loss=0.8792
# Epoch5, Batch82: Loss=0.7626
# Epoch5, Batch83: Loss=0.9556
# Epoch5, Batch84: Loss=0.6239
# Epoch5, Batch85: Loss=0.7671
# Epoch5, Batch86: Loss=0.5848
# Epoch5, Batch87: Loss=0.6064
# Epoch5, Batch88: Loss=0.6217
# Epoch5, Batch89: Loss=0.8270
# Epoch5, Batch90: Loss=0.8359
# Epoch5, Batch91: Loss=0.7349
# Epoch5, Batch92: Loss=0.8473
# Epoch5, Batch93: Loss=0.5804
# Epoch5, Batch94: Loss=0.7162
# Epoch5, Batch95: Loss=0.6488
# Epoch5, Batch96: Loss=0.7670
# Epoch5, Batch97: Loss=0.8201
# Epoch5, Batch98: Loss=0.8606
# Epoch5, Batch99: Loss=0.7923
# Epoch5, Batch100: Loss=0.7686
# Epoch5, Batch101: Loss=0.8316
# Epoch5, Batch102: Loss=0.9054
# Epoch5, Batch103: Loss=0.7220
# Epoch5, Batch104: Loss=0.7904
# Epoch5, Batch105: Loss=0.8628
# Epoch5, Batch106: Loss=0.6342
# Epoch5, Batch107: Loss=0.6247
# Epoch5, Batch108: Loss=1.0617
# Epoch5, Batch109: Loss=0.8843
# Epoch5, Batch110: Loss=0.7174
# Epoch5, Batch111: Loss=0.7191
# Epoch5, Batch112: Loss=0.9467
# Epoch5, Batch113: Loss=0.9521
# Epoch5, Batch114: Loss=0.7814
# Epoch5, Batch115: Loss=0.8240
# Epoch5, Batch116: Loss=0.6763
# Epoch5, Batch117: Loss=0.8166
# Epoch5, Batch118: Loss=0.8871
# Epoch5, Batch119: Loss=0.7509
# Epoch5, Batch120: Loss=0.6023
# Epoch5, Batch121: Loss=0.9078
# Epoch5, Batch122: Loss=0.9202
# Epoch5, Batch123: Loss=0.9479
# Epoch5, Batch124: Loss=0.7344
# Epoch5, Batch125: Loss=0.7500
# Epoch5, Batch126: Loss=0.7781
# Epoch5, Batch127: Loss=0.7131
# Epoch5, Batch128: Loss=0.7100
# Epoch5, Batch129: Loss=0.7992
# Epoch5, Batch130: Loss=0.5778
# Epoch5, Batch131: Loss=0.7346
# Epoch5, Batch132: Loss=0.8536
# Epoch5, Batch133: Loss=0.6401
# Epoch5, Batch134: Loss=0.9655
# Epoch5, Batch135: Loss=0.5811
# Epoch5, Batch136: Loss=0.6536
# Epoch5, Batch137: Loss=0.6330
# Epoch5, Batch138: Loss=0.8775
# Epoch5, Batch139: Loss=0.7946
# Epoch5, Batch140: Loss=0.7451
# Epoch5, Batch141: Loss=0.7606
# Epoch5, Batch142: Loss=0.5562
# Epoch5, Batch143: Loss=0.7795
# Epoch5, Batch144: Loss=0.5622
# Epoch5, Batch145: Loss=0.7651
# Epoch5, Batch146: Loss=0.9275
# Epoch5, Batch147: Loss=0.6718
# Epoch5, Batch148: Loss=0.7782
# Epoch5, Batch149: Loss=0.7261
# Epoch5, Batch150: Loss=0.7086
# Epoch5, Batch151: Loss=0.8211
# Epoch5, Batch152: Loss=0.9978
# Epoch5, Batch153: Loss=0.7631
# Epoch5, Batch154: Loss=0.6479
# Epoch5, Batch155: Loss=0.9117
# Epoch5, Batch156: Loss=0.8239
# Accuracy of pytorch_model set: 0.7072
# Epoch[6], Batch[100/60000], Loss:0.6260654330253601
# Epoch[6], Batch[200/60000], Loss:0.6947648525238037
# Epoch[6], Batch[300/60000], Loss:0.5245646834373474
# Epoch[6], Batch[400/60000], Loss:0.5990944504737854
# Epoch[6], Batch[500/60000], Loss:0.6379755735397339
# Epoch[6], Batch[600/60000], Loss:0.6186995506286621
# Epoch[6], Batch[700/60000], Loss:0.674013614654541
# Epoch[6], Batch[800/60000], Loss:0.6456610560417175
# Epoch[6], Batch[900/60000], Loss:0.9377107620239258
# Accuracy of train set: 0.7419
# Epoch6, Batch0: Loss=0.7162
# Epoch6, Batch1: Loss=0.7398
# Epoch6, Batch2: Loss=0.8129
# Epoch6, Batch3: Loss=0.8977
# Epoch6, Batch4: Loss=0.8005
# Epoch6, Batch5: Loss=0.6303
# Epoch6, Batch6: Loss=0.6880
# Epoch6, Batch7: Loss=0.5962
# Epoch6, Batch8: Loss=0.7614
# Epoch6, Batch9: Loss=0.7314
# Epoch6, Batch10: Loss=1.0017
# Epoch6, Batch11: Loss=0.7102
# Epoch6, Batch12: Loss=0.6785
# Epoch6, Batch13: Loss=0.9363
# Epoch6, Batch14: Loss=0.6809
# Epoch6, Batch15: Loss=0.6502
# Epoch6, Batch16: Loss=0.9112
# Epoch6, Batch17: Loss=0.6948
# Epoch6, Batch18: Loss=0.6635
# Epoch6, Batch19: Loss=0.7903
# Epoch6, Batch20: Loss=0.8591
# Epoch6, Batch21: Loss=0.8707
# Epoch6, Batch22: Loss=0.7499
# Epoch6, Batch23: Loss=0.7353
# Epoch6, Batch24: Loss=0.8190
# Epoch6, Batch25: Loss=0.6772
# Epoch6, Batch26: Loss=0.7605
# Epoch6, Batch27: Loss=0.9083
# Epoch6, Batch28: Loss=0.5114
# Epoch6, Batch29: Loss=0.5999
# Epoch6, Batch30: Loss=0.8422
# Epoch6, Batch31: Loss=0.7382
# Epoch6, Batch32: Loss=0.5673
# Epoch6, Batch33: Loss=0.7343
# Epoch6, Batch34: Loss=0.9047
# Epoch6, Batch35: Loss=0.5814
# Epoch6, Batch36: Loss=0.7806
# Epoch6, Batch37: Loss=0.7293
# Epoch6, Batch38: Loss=0.8704
# Epoch6, Batch39: Loss=0.6089
# Epoch6, Batch40: Loss=0.7216
# Epoch6, Batch41: Loss=0.7943
# Epoch6, Batch42: Loss=0.7235
# Epoch6, Batch43: Loss=0.8424
# Epoch6, Batch44: Loss=0.8133
# Epoch6, Batch45: Loss=0.7231
# Epoch6, Batch46: Loss=0.5928
# Epoch6, Batch47: Loss=0.5945
# Epoch6, Batch48: Loss=0.4393
# Epoch6, Batch49: Loss=0.7780
# Epoch6, Batch50: Loss=0.6767
# Epoch6, Batch51: Loss=0.7820
# Epoch6, Batch52: Loss=0.8727
# Epoch6, Batch53: Loss=1.0287
# Epoch6, Batch54: Loss=0.9434
# Epoch6, Batch55: Loss=0.7020
# Epoch6, Batch56: Loss=0.9983
# Epoch6, Batch57: Loss=0.6217
# Epoch6, Batch58: Loss=0.6335
# Epoch6, Batch59: Loss=1.0532
# Epoch6, Batch60: Loss=0.6817
# Epoch6, Batch61: Loss=0.8039
# Epoch6, Batch62: Loss=0.8141
# Epoch6, Batch63: Loss=0.6333
# Epoch6, Batch64: Loss=0.4577
# Epoch6, Batch65: Loss=0.7683
# Epoch6, Batch66: Loss=0.8542
# Epoch6, Batch67: Loss=0.6614
# Epoch6, Batch68: Loss=0.7673
# Epoch6, Batch69: Loss=0.6913
# Epoch6, Batch70: Loss=0.9515
# Epoch6, Batch71: Loss=0.6854
# Epoch6, Batch72: Loss=0.6415
# Epoch6, Batch73: Loss=0.6824
# Epoch6, Batch74: Loss=0.8092
# Epoch6, Batch75: Loss=0.7466
# Epoch6, Batch76: Loss=0.7299
# Epoch6, Batch77: Loss=0.6270
# Epoch6, Batch78: Loss=0.5670
# Epoch6, Batch79: Loss=0.7653
# Epoch6, Batch80: Loss=0.8402
# Epoch6, Batch81: Loss=0.5265
# Epoch6, Batch82: Loss=0.7299
# Epoch6, Batch83: Loss=0.7691
# Epoch6, Batch84: Loss=0.8072
# Epoch6, Batch85: Loss=0.8724
# Epoch6, Batch86: Loss=0.7189
# Epoch6, Batch87: Loss=0.7319
# Epoch6, Batch88: Loss=0.7137
# Epoch6, Batch89: Loss=0.7762
# Epoch6, Batch90: Loss=0.9489
# Epoch6, Batch91: Loss=0.6486
# Epoch6, Batch92: Loss=1.0977
# Epoch6, Batch93: Loss=0.8971
# Epoch6, Batch94: Loss=0.5800
# Epoch6, Batch95: Loss=0.6657
# Epoch6, Batch96: Loss=0.8187
# Epoch6, Batch97: Loss=0.7536
# Epoch6, Batch98: Loss=0.7710
# Epoch6, Batch99: Loss=0.5694
# Epoch6, Batch100: Loss=0.6097
# Epoch6, Batch101: Loss=0.7433
# Epoch6, Batch102: Loss=0.7281
# Epoch6, Batch103: Loss=0.8682
# Epoch6, Batch104: Loss=0.7790
# Epoch6, Batch105: Loss=0.7979
# Epoch6, Batch106: Loss=0.8171
# Epoch6, Batch107: Loss=0.5313
# Epoch6, Batch108: Loss=0.5010
# Epoch6, Batch109: Loss=0.7932
# Epoch6, Batch110: Loss=0.5092
# Epoch6, Batch111: Loss=0.9052
# Epoch6, Batch112: Loss=0.6558
# Epoch6, Batch113: Loss=0.7661
# Epoch6, Batch114: Loss=0.7234
# Epoch6, Batch115: Loss=0.8389
# Epoch6, Batch116: Loss=0.8420
# Epoch6, Batch117: Loss=0.6491
# Epoch6, Batch118: Loss=0.7616
# Epoch6, Batch119: Loss=0.8855
# Epoch6, Batch120: Loss=0.6038
# Epoch6, Batch121: Loss=0.8949
# Epoch6, Batch122: Loss=0.5521
# Epoch6, Batch123: Loss=0.6044
# Epoch6, Batch124: Loss=0.5844
# Epoch6, Batch125: Loss=0.7962
# Epoch6, Batch126: Loss=0.8163
# Epoch6, Batch127: Loss=0.5320
# Epoch6, Batch128: Loss=0.6102
# Epoch6, Batch129: Loss=0.5170
# Epoch6, Batch130: Loss=0.8461
# Epoch6, Batch131: Loss=0.6511
# Epoch6, Batch132: Loss=0.8716
# Epoch6, Batch133: Loss=0.7159
# Epoch6, Batch134: Loss=0.7505
# Epoch6, Batch135: Loss=0.5169
# Epoch6, Batch136: Loss=0.8593
# Epoch6, Batch137: Loss=0.5634
# Epoch6, Batch138: Loss=0.6776
# Epoch6, Batch139: Loss=0.5916
# Epoch6, Batch140: Loss=0.6704
# Epoch6, Batch141: Loss=0.5820
# Epoch6, Batch142: Loss=0.9072
# Epoch6, Batch143: Loss=0.7490
# Epoch6, Batch144: Loss=0.7788
# Epoch6, Batch145: Loss=0.6863
# Epoch6, Batch146: Loss=0.8106
# Epoch6, Batch147: Loss=1.0574
# Epoch6, Batch148: Loss=0.7340
# Epoch6, Batch149: Loss=0.6936
# Epoch6, Batch150: Loss=0.8639
# Epoch6, Batch151: Loss=0.8391
# Epoch6, Batch152: Loss=0.6644
# Epoch6, Batch153: Loss=0.7685
# Epoch6, Batch154: Loss=0.8355
# Epoch6, Batch155: Loss=0.6660
# Epoch6, Batch156: Loss=0.5023
# Accuracy of pytorch_model set: 0.7325
# Epoch[7], Batch[100/60000], Loss:0.7961611151695251
# Epoch[7], Batch[200/60000], Loss:0.7348210215568542
# Epoch[7], Batch[300/60000], Loss:0.63169926404953
# Epoch[7], Batch[400/60000], Loss:0.55388343334198
# Epoch[7], Batch[500/60000], Loss:0.7939816117286682
# Epoch[7], Batch[600/60000], Loss:0.6317646503448486
# Epoch[7], Batch[700/60000], Loss:0.46459245681762695
# Epoch[7], Batch[800/60000], Loss:0.6908695101737976
# Epoch[7], Batch[900/60000], Loss:0.5789181590080261
# Accuracy of train set: 0.7686166666666666
# Epoch7, Batch0: Loss=0.3291
# Epoch7, Batch1: Loss=0.7345
# Epoch7, Batch2: Loss=0.8538
# Epoch7, Batch3: Loss=0.4639
# Epoch7, Batch4: Loss=0.8308
# Epoch7, Batch5: Loss=0.7997
# Epoch7, Batch6: Loss=0.7199
# Epoch7, Batch7: Loss=0.6872
# Epoch7, Batch8: Loss=0.6564
# Epoch7, Batch9: Loss=0.5074
# Epoch7, Batch10: Loss=0.7933
# Epoch7, Batch11: Loss=0.6028
# Epoch7, Batch12: Loss=0.6076
# Epoch7, Batch13: Loss=0.4138
# Epoch7, Batch14: Loss=0.6500
# Epoch7, Batch15: Loss=0.5459
# Epoch7, Batch16: Loss=0.8901
# Epoch7, Batch17: Loss=0.5783
# Epoch7, Batch18: Loss=0.5492
# Epoch7, Batch19: Loss=0.7276
# Epoch7, Batch20: Loss=0.6001
# Epoch7, Batch21: Loss=0.7246
# Epoch7, Batch22: Loss=0.7054
# Epoch7, Batch23: Loss=0.5747
# Epoch7, Batch24: Loss=0.5104
# Epoch7, Batch25: Loss=0.5093
# Epoch7, Batch26: Loss=0.5428
# Epoch7, Batch27: Loss=0.7059
# Epoch7, Batch28: Loss=0.5096
# Epoch7, Batch29: Loss=0.5130
# Epoch7, Batch30: Loss=0.6371
# Epoch7, Batch31: Loss=0.7364
# Epoch7, Batch32: Loss=0.6541
# Epoch7, Batch33: Loss=0.9008
# Epoch7, Batch34: Loss=0.7655
# Epoch7, Batch35: Loss=0.5118
# Epoch7, Batch36: Loss=0.6993
# Epoch7, Batch37: Loss=0.5357
# Epoch7, Batch38: Loss=0.6802
# Epoch7, Batch39: Loss=0.4865
# Epoch7, Batch40: Loss=0.5350
# Epoch7, Batch41: Loss=0.4943
# Epoch7, Batch42: Loss=0.7397
# Epoch7, Batch43: Loss=0.7357
# Epoch7, Batch44: Loss=0.5803
# Epoch7, Batch45: Loss=0.6644
# Epoch7, Batch46: Loss=0.6338
# Epoch7, Batch47: Loss=0.7216
# Epoch7, Batch48: Loss=0.5236
# Epoch7, Batch49: Loss=0.8679
# Epoch7, Batch50: Loss=0.6982
# Epoch7, Batch51: Loss=0.5611
# Epoch7, Batch52: Loss=0.5851
# Epoch7, Batch53: Loss=0.6575
# Epoch7, Batch54: Loss=0.7302
# Epoch7, Batch55: Loss=0.7149
# Epoch7, Batch56: Loss=0.6980
# Epoch7, Batch57: Loss=1.0429
# Epoch7, Batch58: Loss=0.7609
# Epoch7, Batch59: Loss=0.7244
# Epoch7, Batch60: Loss=0.6326
# Epoch7, Batch61: Loss=0.6820
# Epoch7, Batch62: Loss=0.5357
# Epoch7, Batch63: Loss=0.6416
# Epoch7, Batch64: Loss=0.7418
# Epoch7, Batch65: Loss=0.5087
# Epoch7, Batch66: Loss=0.6265
# Epoch7, Batch67: Loss=0.5917
# Epoch7, Batch68: Loss=0.7510
# Epoch7, Batch69: Loss=0.4747
# Epoch7, Batch70: Loss=0.4948
# Epoch7, Batch71: Loss=0.6980
# Epoch7, Batch72: Loss=0.6084
# Epoch7, Batch73: Loss=0.7568
# Epoch7, Batch74: Loss=0.6005
# Epoch7, Batch75: Loss=0.6442
# Epoch7, Batch76: Loss=0.6288
# Epoch7, Batch77: Loss=0.5724
# Epoch7, Batch78: Loss=0.7160
# Epoch7, Batch79: Loss=0.6822
# Epoch7, Batch80: Loss=0.9921
# Epoch7, Batch81: Loss=0.7496
# Epoch7, Batch82: Loss=0.7250
# Epoch7, Batch83: Loss=0.4671
# Epoch7, Batch84: Loss=0.6470
# Epoch7, Batch85: Loss=0.8267
# Epoch7, Batch86: Loss=0.6121
# Epoch7, Batch87: Loss=0.6650
# Epoch7, Batch88: Loss=0.6366
# Epoch7, Batch89: Loss=0.5638
# Epoch7, Batch90: Loss=0.5155
# Epoch7, Batch91: Loss=0.7140
# Epoch7, Batch92: Loss=0.8990
# Epoch7, Batch93: Loss=0.5346
# Epoch7, Batch94: Loss=0.5440
# Epoch7, Batch95: Loss=0.7259
# Epoch7, Batch96: Loss=0.6304
# Epoch7, Batch97: Loss=0.5398
# Epoch7, Batch98: Loss=0.7218
# Epoch7, Batch99: Loss=0.6259
# Epoch7, Batch100: Loss=0.8692
# Epoch7, Batch101: Loss=0.4978
# Epoch7, Batch102: Loss=0.5575
# Epoch7, Batch103: Loss=0.5390
# Epoch7, Batch104: Loss=0.6696
# Epoch7, Batch105: Loss=0.6298
# Epoch7, Batch106: Loss=0.6115
# Epoch7, Batch107: Loss=0.5900
# Epoch7, Batch108: Loss=0.5619
# Epoch7, Batch109: Loss=0.6597
# Epoch7, Batch110: Loss=0.6534
# Epoch7, Batch111: Loss=0.6642
# Epoch7, Batch112: Loss=0.6084
# Epoch7, Batch113: Loss=0.6531
# Epoch7, Batch114: Loss=0.5991
# Epoch7, Batch115: Loss=0.6020
# Epoch7, Batch116: Loss=0.5069
# Epoch7, Batch117: Loss=0.6487
# Epoch7, Batch118: Loss=0.5135
# Epoch7, Batch119: Loss=0.5346
# Epoch7, Batch120: Loss=0.7226
# Epoch7, Batch121: Loss=0.6017
# Epoch7, Batch122: Loss=0.6547
# Epoch7, Batch123: Loss=0.9208
# Epoch7, Batch124: Loss=0.5047
# Epoch7, Batch125: Loss=0.5961
# Epoch7, Batch126: Loss=0.9342
# Epoch7, Batch127: Loss=0.5485
# Epoch7, Batch128: Loss=0.8137
# Epoch7, Batch129: Loss=0.5382
# Epoch7, Batch130: Loss=0.8201
# Epoch7, Batch131: Loss=0.5943
# Epoch7, Batch132: Loss=0.6636
# Epoch7, Batch133: Loss=0.5868
# Epoch7, Batch134: Loss=0.5876
# Epoch7, Batch135: Loss=0.7419
# Epoch7, Batch136: Loss=0.5503
# Epoch7, Batch137: Loss=0.7025
# Epoch7, Batch138: Loss=0.6798
# Epoch7, Batch139: Loss=0.5385
# Epoch7, Batch140: Loss=0.6551
# Epoch7, Batch141: Loss=0.7129
# Epoch7, Batch142: Loss=0.8629
# Epoch7, Batch143: Loss=0.8612
# Epoch7, Batch144: Loss=0.6994
# Epoch7, Batch145: Loss=0.4845
# Epoch7, Batch146: Loss=0.8001
# Epoch7, Batch147: Loss=0.6351
# Epoch7, Batch148: Loss=0.6751
# Epoch7, Batch149: Loss=0.6646
# Epoch7, Batch150: Loss=0.6380
# Epoch7, Batch151: Loss=0.5434
# Epoch7, Batch152: Loss=0.6634
# Epoch7, Batch153: Loss=0.6496
# Epoch7, Batch154: Loss=0.6359
# Epoch7, Batch155: Loss=0.6248
# Epoch7, Batch156: Loss=0.3343
# Accuracy of pytorch_model set: 0.768
# Epoch[8], Batch[100/60000], Loss:0.4689757823944092
# Epoch[8], Batch[200/60000], Loss:0.7638875246047974
# Epoch[8], Batch[300/60000], Loss:0.5471925735473633
# Epoch[8], Batch[400/60000], Loss:0.6236237287521362
# Epoch[8], Batch[500/60000], Loss:0.9174907207489014
# Epoch[8], Batch[600/60000], Loss:0.4909064471721649
# Epoch[8], Batch[700/60000], Loss:0.6832422614097595
# Epoch[8], Batch[800/60000], Loss:0.6495319604873657
# Epoch[8], Batch[900/60000], Loss:0.6626883745193481
# Accuracy of train set: 0.7831666666666667
# Epoch8, Batch0: Loss=0.6713
# Epoch8, Batch1: Loss=0.6715
# Epoch8, Batch2: Loss=0.6882
# Epoch8, Batch3: Loss=0.7842
# Epoch8, Batch4: Loss=0.4400
# Epoch8, Batch5: Loss=0.7321
# Epoch8, Batch6: Loss=0.5829
# Epoch8, Batch7: Loss=0.5650
# Epoch8, Batch8: Loss=0.6636
# Epoch8, Batch9: Loss=0.4458
# Epoch8, Batch10: Loss=0.5635
# Epoch8, Batch11: Loss=0.8275
# Epoch8, Batch12: Loss=0.4484
# Epoch8, Batch13: Loss=0.7573
# Epoch8, Batch14: Loss=0.6379
# Epoch8, Batch15: Loss=0.5540
# Epoch8, Batch16: Loss=0.8414
# Epoch8, Batch17: Loss=0.4805
# Epoch8, Batch18: Loss=0.6366
# Epoch8, Batch19: Loss=0.5138
# Epoch8, Batch20: Loss=0.6880
# Epoch8, Batch21: Loss=0.7394
# Epoch8, Batch22: Loss=0.6790
# Epoch8, Batch23: Loss=0.5950
# Epoch8, Batch24: Loss=0.6135
# Epoch8, Batch25: Loss=0.7495
# Epoch8, Batch26: Loss=0.6807
# Epoch8, Batch27: Loss=0.5446
# Epoch8, Batch28: Loss=0.6067
# Epoch8, Batch29: Loss=0.5212
# Epoch8, Batch30: Loss=0.6952
# Epoch8, Batch31: Loss=0.6581
# Epoch8, Batch32: Loss=0.6048
# Epoch8, Batch33: Loss=0.5191
# Epoch8, Batch34: Loss=0.5120
# Epoch8, Batch35: Loss=0.6948
# Epoch8, Batch36: Loss=0.6738
# Epoch8, Batch37: Loss=0.6489
# Epoch8, Batch38: Loss=0.5322
# Epoch8, Batch39: Loss=0.6552
# Epoch8, Batch40: Loss=0.7022
# Epoch8, Batch41: Loss=0.4037
# Epoch8, Batch42: Loss=0.7301
# Epoch8, Batch43: Loss=0.5649
# Epoch8, Batch44: Loss=0.4984
# Epoch8, Batch45: Loss=0.7238
# Epoch8, Batch46: Loss=0.7602
# Epoch8, Batch47: Loss=0.6122
# Epoch8, Batch48: Loss=0.6963
# Epoch8, Batch49: Loss=0.5880
# Epoch8, Batch50: Loss=0.5168
# Epoch8, Batch51: Loss=0.7667
# Epoch8, Batch52: Loss=0.5926
# Epoch8, Batch53: Loss=0.5132
# Epoch8, Batch54: Loss=0.5759
# Epoch8, Batch55: Loss=0.5520
# Epoch8, Batch56: Loss=0.3729
# Epoch8, Batch57: Loss=0.4770
# Epoch8, Batch58: Loss=0.7279
# Epoch8, Batch59: Loss=0.5701
# Epoch8, Batch60: Loss=0.5891
# Epoch8, Batch61: Loss=0.6736
# Epoch8, Batch62: Loss=0.7200
# Epoch8, Batch63: Loss=0.8340
# Epoch8, Batch64: Loss=0.6296
# Epoch8, Batch65: Loss=0.5402
# Epoch8, Batch66: Loss=0.5034
# Epoch8, Batch67: Loss=0.6793
# Epoch8, Batch68: Loss=0.8289
# Epoch8, Batch69: Loss=0.9541
# Epoch8, Batch70: Loss=0.8104
# Epoch8, Batch71: Loss=0.7004
# Epoch8, Batch72: Loss=0.6944
# Epoch8, Batch73: Loss=0.4711
# Epoch8, Batch74: Loss=0.4999
# Epoch8, Batch75: Loss=0.5727
# Epoch8, Batch76: Loss=0.6747
# Epoch8, Batch77: Loss=0.4722
# Epoch8, Batch78: Loss=0.6149
# Epoch8, Batch79: Loss=0.6371
# Epoch8, Batch80: Loss=0.6395
# Epoch8, Batch81: Loss=0.6898
# Epoch8, Batch82: Loss=0.6654
# Epoch8, Batch83: Loss=0.7095
# Epoch8, Batch84: Loss=0.5762
# Epoch8, Batch85: Loss=0.5880
# Epoch8, Batch86: Loss=0.5589
# Epoch8, Batch87: Loss=0.6204
# Epoch8, Batch88: Loss=0.5363
# Epoch8, Batch89: Loss=0.5905
# Epoch8, Batch90: Loss=0.7124
# Epoch8, Batch91: Loss=0.7635
# Epoch8, Batch92: Loss=0.4942
# Epoch8, Batch93: Loss=0.5185
# Epoch8, Batch94: Loss=0.6031
# Epoch8, Batch95: Loss=0.6664
# Epoch8, Batch96: Loss=0.6724
# Epoch8, Batch97: Loss=0.4809
# Epoch8, Batch98: Loss=0.8822
# Epoch8, Batch99: Loss=0.4761
# Epoch8, Batch100: Loss=0.5377
# Epoch8, Batch101: Loss=0.7272
# Epoch8, Batch102: Loss=0.5395
# Epoch8, Batch103: Loss=0.4025
# Epoch8, Batch104: Loss=0.6765
# Epoch8, Batch105: Loss=0.5798
# Epoch8, Batch106: Loss=0.7713
# Epoch8, Batch107: Loss=0.7008
# Epoch8, Batch108: Loss=0.8195
# Epoch8, Batch109: Loss=0.6517
# Epoch8, Batch110: Loss=0.5703
# Epoch8, Batch111: Loss=0.4575
# Epoch8, Batch112: Loss=0.6079
# Epoch8, Batch113: Loss=0.7830
# Epoch8, Batch114: Loss=0.5085
# Epoch8, Batch115: Loss=0.7601
# Epoch8, Batch116: Loss=0.5044
# Epoch8, Batch117: Loss=0.5398
# Epoch8, Batch118: Loss=0.5962
# Epoch8, Batch119: Loss=0.5582
# Epoch8, Batch120: Loss=0.6890
# Epoch8, Batch121: Loss=0.5374
# Epoch8, Batch122: Loss=0.7439
# Epoch8, Batch123: Loss=0.8401
# Epoch8, Batch124: Loss=0.7451
# Epoch8, Batch125: Loss=0.4766
# Epoch8, Batch126: Loss=0.7332
# Epoch8, Batch127: Loss=0.5662
# Epoch8, Batch128: Loss=0.8657
# Epoch8, Batch129: Loss=0.7405
# Epoch8, Batch130: Loss=0.6599
# Epoch8, Batch131: Loss=0.5226
# Epoch8, Batch132: Loss=0.5160
# Epoch8, Batch133: Loss=0.6163
# Epoch8, Batch134: Loss=0.5836
# Epoch8, Batch135: Loss=0.7047
# Epoch8, Batch136: Loss=0.5912
# Epoch8, Batch137: Loss=0.5618
# Epoch8, Batch138: Loss=0.5434
# Epoch8, Batch139: Loss=0.5668
# Epoch8, Batch140: Loss=0.5984
# Epoch8, Batch141: Loss=0.5719
# Epoch8, Batch142: Loss=0.7137
# Epoch8, Batch143: Loss=0.5788
# Epoch8, Batch144: Loss=0.6303
# Epoch8, Batch145: Loss=0.7361
# Epoch8, Batch146: Loss=0.6096
# Epoch8, Batch147: Loss=0.7424
# Epoch8, Batch148: Loss=0.4923
# Epoch8, Batch149: Loss=0.6091
# Epoch8, Batch150: Loss=0.5310
# Epoch8, Batch151: Loss=0.6751
# Epoch8, Batch152: Loss=0.4811
# Epoch8, Batch153: Loss=0.6818
# Epoch8, Batch154: Loss=0.5160
# Epoch8, Batch155: Loss=0.5087
# Epoch8, Batch156: Loss=0.6042
# Accuracy of pytorch_model set: 0.7793
# Epoch[9], Batch[100/60000], Loss:0.4815998077392578
# Epoch[9], Batch[200/60000], Loss:0.8942084312438965
# Epoch[9], Batch[300/60000], Loss:0.6855077743530273
# Epoch[9], Batch[400/60000], Loss:0.8606218695640564
# Epoch[9], Batch[500/60000], Loss:0.4913276731967926
# Epoch[9], Batch[600/60000], Loss:0.6802777647972107
# Epoch[9], Batch[700/60000], Loss:0.7406136989593506
# Epoch[9], Batch[800/60000], Loss:0.9192315340042114
# Epoch[9], Batch[900/60000], Loss:0.679764449596405
# Accuracy of train set: 0.79655
# Epoch9, Batch0: Loss=0.6189
# Epoch9, Batch1: Loss=0.7812
# Epoch9, Batch2: Loss=0.8073
# Epoch9, Batch3: Loss=0.6069
# Epoch9, Batch4: Loss=0.5888
# Epoch9, Batch5: Loss=0.7200
# Epoch9, Batch6: Loss=0.5884
# Epoch9, Batch7: Loss=0.7646
# Epoch9, Batch8: Loss=1.0050
# Epoch9, Batch9: Loss=0.5018
# Epoch9, Batch10: Loss=0.5312
# Epoch9, Batch11: Loss=0.7053
# Epoch9, Batch12: Loss=0.6204
# Epoch9, Batch13: Loss=0.5921
# Epoch9, Batch14: Loss=0.6615
# Epoch9, Batch15: Loss=0.5268
# Epoch9, Batch16: Loss=0.5003
# Epoch9, Batch17: Loss=0.5011
# Epoch9, Batch18: Loss=0.5597
# Epoch9, Batch19: Loss=0.5238
# Epoch9, Batch20: Loss=0.7012
# Epoch9, Batch21: Loss=0.4774
# Epoch9, Batch22: Loss=0.7176
# Epoch9, Batch23: Loss=0.5070
# Epoch9, Batch24: Loss=0.6274
# Epoch9, Batch25: Loss=0.7557
# Epoch9, Batch26: Loss=0.5766
# Epoch9, Batch27: Loss=0.6051
# Epoch9, Batch28: Loss=0.5442
# Epoch9, Batch29: Loss=0.5298
# Epoch9, Batch30: Loss=0.7624
# Epoch9, Batch31: Loss=0.6823
# Epoch9, Batch32: Loss=0.7321
# Epoch9, Batch33: Loss=0.5267
# Epoch9, Batch34: Loss=0.5068
# Epoch9, Batch35: Loss=0.6453
# Epoch9, Batch36: Loss=0.6780
# Epoch9, Batch37: Loss=0.5505
# Epoch9, Batch38: Loss=0.4745
# Epoch9, Batch39: Loss=0.5316
# Epoch9, Batch40: Loss=0.5752
# Epoch9, Batch41: Loss=0.6964
# ...
# Accuracy of pytorch_model set: 0.8278
# Epoch[22], Batch[100/60000], Loss:0.35743609070777893
# Epoch[22], Batch[200/60000], Loss:0.3903994560241699
# Epoch[22], Batch[300/60000], Loss:0.3093360364437103
# Epoch[22], Batch[400/60000], Loss:0.3900001645088196
# Epoch[22], Batch[500/60000], Loss:0.2834398150444031
# Epoch[22], Batch[600/60000], Loss:0.5599668622016907
# Epoch[22], Batch[700/60000], Loss:0.39290323853492737
# Epoch[22], Batch[800/60000], Loss:0.4324323832988739
# Epoch[22], Batch[900/60000], Loss:0.4230633080005646
# Accuracy of train set: 0.8584333333333334
# Epoch22, Batch0: Loss=0.6075
# Epoch22, Batch1: Loss=0.3419
# Epoch22, Batch2: Loss=0.4280
# Epoch22, Batch3: Loss=0.4516
# Epoch22, Batch4: Loss=0.3896
# Epoch22, Batch5: Loss=0.3461
# Epoch22, Batch6: Loss=0.4369
# Epoch22, Batch7: Loss=0.3244
# Epoch22, Batch8: Loss=0.5500
# Epoch22, Batch9: Loss=0.5138
# Epoch22, Batch10: Loss=0.3546
# Epoch22, Batch11: Loss=0.3193
# Epoch22, Batch12: Loss=0.4876
# Epoch22, Batch13: Loss=0.4207
# Epoch22, Batch14: Loss=0.4433
# Epoch22, Batch15: Loss=0.5118
# Epoch22, Batch16: Loss=0.4088
# Epoch22, Batch17: Loss=0.4673
# Epoch22, Batch18: Loss=0.6419
# Epoch22, Batch19: Loss=0.3985
# Epoch22, Batch20: Loss=0.2712
# Epoch22, Batch21: Loss=0.3883
# Epoch22, Batch22: Loss=0.5294
# Epoch22, Batch23: Loss=0.3784
# Epoch22, Batch24: Loss=0.4414
# Epoch22, Batch25: Loss=0.6095
# Epoch22, Batch26: Loss=0.5670
# Epoch22, Batch27: Loss=0.5717
# Epoch22, Batch28: Loss=0.5324
# Epoch22, Batch29: Loss=0.3154
# Epoch22, Batch30: Loss=0.4216
# Epoch22, Batch31: Loss=0.5660
# Epoch22, Batch32: Loss=0.7300
# Epoch22, Batch33: Loss=0.3891
# Epoch22, Batch34: Loss=0.3565
# Epoch22, Batch35: Loss=0.3682
# Epoch22, Batch36: Loss=0.3547
# Epoch22, Batch37: Loss=0.3755
# Epoch22, Batch38: Loss=0.4715
# Epoch22, Batch39: Loss=0.4766
# Epoch22, Batch40: Loss=0.6635
# Epoch22, Batch41: Loss=0.4207
# Epoch22, Batch42: Loss=0.5502
# Epoch22, Batch43: Loss=0.4368
# Epoch22, Batch44: Loss=0.4497
# Epoch22, Batch45: Loss=0.5484
# Epoch22, Batch46: Loss=0.6275
# Epoch22, Batch47: Loss=0.6540
# Epoch22, Batch48: Loss=0.3700
# Epoch22, Batch49: Loss=0.4254
# Epoch22, Batch50: Loss=0.3461
# Epoch22, Batch51: Loss=0.4263
# Epoch22, Batch52: Loss=0.4921
# Epoch22, Batch53: Loss=0.4334
# Epoch22, Batch54: Loss=0.3748
# Epoch22, Batch55: Loss=0.6308
# Epoch22, Batch56: Loss=0.4690
# Epoch22, Batch57: Loss=0.2617
# Epoch22, Batch58: Loss=0.6486
# Epoch22, Batch59: Loss=0.3296
# Epoch22, Batch60: Loss=0.4591
# Epoch22, Batch61: Loss=0.4323
# Epoch22, Batch62: Loss=0.3059
# Epoch22, Batch63: Loss=0.5605
# Epoch22, Batch64: Loss=0.5131
# Epoch22, Batch65: Loss=0.4625
# Epoch22, Batch66: Loss=0.2605
# Epoch22, Batch67: Loss=0.5607
# Epoch22, Batch68: Loss=0.4299
# Epoch22, Batch69: Loss=0.4761
# Epoch22, Batch70: Loss=0.3827
# Epoch22, Batch71: Loss=0.4921
# Epoch22, Batch72: Loss=0.3742
# Epoch22, Batch73: Loss=0.4270
# Epoch22, Batch74: Loss=0.5202
# Epoch22, Batch75: Loss=0.7896
# Epoch22, Batch76: Loss=0.5351
# Epoch22, Batch77: Loss=0.3285
# Epoch22, Batch78: Loss=0.5964
# Epoch22, Batch79: Loss=0.5917
# Epoch22, Batch80: Loss=0.3320
# Epoch22, Batch81: Loss=0.6621
# Epoch22, Batch82: Loss=0.4093
# Epoch22, Batch83: Loss=0.2432
# Epoch22, Batch84: Loss=0.4312
# Epoch22, Batch85: Loss=0.4328
# Epoch22, Batch86: Loss=0.4472
# Epoch22, Batch87: Loss=0.3096
# Epoch22, Batch88: Loss=0.4661
# Epoch22, Batch89: Loss=0.3279
# Epoch22, Batch90: Loss=0.3960
# Epoch22, Batch91: Loss=0.4740
# Epoch22, Batch92: Loss=0.3564
# Epoch22, Batch93: Loss=0.4572
# Epoch22, Batch94: Loss=0.5718
# Epoch22, Batch95: Loss=0.4107
# Epoch22, Batch96: Loss=0.4418
# Epoch22, Batch97: Loss=0.3239
# Epoch22, Batch98: Loss=0.4829
# Epoch22, Batch99: Loss=0.5872
# Epoch22, Batch100: Loss=0.3867
# Epoch22, Batch101: Loss=0.4003
# Epoch22, Batch102: Loss=0.2409
# Epoch22, Batch103: Loss=0.5329
# Epoch22, Batch104: Loss=0.6963
# Epoch22, Batch105: Loss=0.5861
# Epoch22, Batch106: Loss=0.6189
# Epoch22, Batch107: Loss=0.2984
# Epoch22, Batch108: Loss=0.4213
# Epoch22, Batch109: Loss=0.4390
# Epoch22, Batch110: Loss=0.3683
# Epoch22, Batch111: Loss=0.5067
# Epoch22, Batch112: Loss=0.5282
# Epoch22, Batch113: Loss=0.4414
# Epoch22, Batch114: Loss=0.3192
# Epoch22, Batch115: Loss=0.4387
# Epoch22, Batch116: Loss=0.4108
# Epoch22, Batch117: Loss=0.4627
# Epoch22, Batch118: Loss=0.4900
# Epoch22, Batch119: Loss=0.4884
# Epoch22, Batch120: Loss=0.6796
# Epoch22, Batch121: Loss=0.4563
# Epoch22, Batch122: Loss=0.5346
# Epoch22, Batch123: Loss=0.3916
# Epoch22, Batch124: Loss=0.1985
# Epoch22, Batch125: Loss=0.5416
# Epoch22, Batch126: Loss=0.5075
# Epoch22, Batch127: Loss=0.2253
# Epoch22, Batch128: Loss=0.5717
# Epoch22, Batch129: Loss=0.2899
# Epoch22, Batch130: Loss=0.4463
# Epoch22, Batch131: Loss=0.4064
# Epoch22, Batch132: Loss=0.3856
# Epoch22, Batch133: Loss=0.5093
# Epoch22, Batch134: Loss=0.4778
# Epoch22, Batch135: Loss=0.6419
# Epoch22, Batch136: Loss=0.3247
# Epoch22, Batch137: Loss=0.8548
# Epoch22, Batch138: Loss=0.3467
# Epoch22, Batch139: Loss=0.2601
# Epoch22, Batch140: Loss=0.4478
# Epoch22, Batch141: Loss=0.6057
# Epoch22, Batch142: Loss=0.4524
# Epoch22, Batch143: Loss=0.3235
# Epoch22, Batch144: Loss=0.3993
# Epoch22, Batch145: Loss=0.4030
# Epoch22, Batch146: Loss=0.3567
# Epoch22, Batch147: Loss=0.4051
# Epoch22, Batch148: Loss=0.2608
# Epoch22, Batch149: Loss=0.5033
# Epoch22, Batch150: Loss=0.4683
# Epoch22, Batch151: Loss=0.4749
# Epoch22, Batch152: Loss=0.6452
# Epoch22, Batch153: Loss=0.2314
# Epoch22, Batch154: Loss=0.7843
# Epoch22, Batch155: Loss=0.3238
# Epoch22, Batch156: Loss=0.1843
# Accuracy of pytorch_model set: 0.8402
# Epoch[23], Batch[100/60000], Loss:0.4033745229244232
# Epoch[23], Batch[200/60000], Loss:0.4797161817550659
# Epoch[23], Batch[300/60000], Loss:0.39354634284973145
# Epoch[23], Batch[400/60000], Loss:0.41538435220718384
# Epoch[23], Batch[500/60000], Loss:0.5369102954864502
# Epoch[23], Batch[600/60000], Loss:0.321144700050354
# Epoch[23], Batch[700/60000], Loss:0.25056520104408264
# Epoch[23], Batch[800/60000], Loss:0.45813626050949097
# Epoch[23], Batch[900/60000], Loss:0.4338306188583374
# Accuracy of train set: 0.86015
# Epoch23, Batch0: Loss=0.3135
# Epoch23, Batch1: Loss=0.4271
# Epoch23, Batch2: Loss=0.3831
# Epoch23, Batch3: Loss=0.4382
# Epoch23, Batch4: Loss=0.4029
# Epoch23, Batch5: Loss=0.4699
# Epoch23, Batch6: Loss=0.4907
# Epoch23, Batch7: Loss=0.4908
# Epoch23, Batch8: Loss=0.2576
# Epoch23, Batch9: Loss=0.4136
# Epoch23, Batch10: Loss=0.3534
# Epoch23, Batch11: Loss=0.4266
# Epoch23, Batch12: Loss=0.6694
# Epoch23, Batch13: Loss=0.5517
# Epoch23, Batch14: Loss=0.5932
# Epoch23, Batch15: Loss=0.5514
# Epoch23, Batch16: Loss=0.3962
# Epoch23, Batch17: Loss=0.3312
# Epoch23, Batch18: Loss=0.4013
# Epoch23, Batch19: Loss=0.2400
# Epoch23, Batch20: Loss=0.3765
# Epoch23, Batch21: Loss=0.3331
# Epoch23, Batch22: Loss=0.4713
# Epoch23, Batch23: Loss=0.3832
# Epoch23, Batch24: Loss=0.7736
# Epoch23, Batch25: Loss=0.5822
# Epoch23, Batch26: Loss=0.5558
# Epoch23, Batch27: Loss=0.4675
# Epoch23, Batch28: Loss=0.2288
# Epoch23, Batch29: Loss=0.4822
# Epoch23, Batch30: Loss=0.2275
# Epoch23, Batch31: Loss=0.4714
# Epoch23, Batch32: Loss=0.3334
# Epoch23, Batch33: Loss=0.3411
# Epoch23, Batch34: Loss=0.3519
# Epoch23, Batch35: Loss=0.5016
# Epoch23, Batch36: Loss=0.3330
# Epoch23, Batch37: Loss=0.3310
# Epoch23, Batch38: Loss=0.4286
# Epoch23, Batch39: Loss=0.5974
# Epoch23, Batch40: Loss=0.5212
# Epoch23, Batch41: Loss=0.3140
# Epoch23, Batch42: Loss=0.3804
# Epoch23, Batch43: Loss=0.5683
# Epoch23, Batch44: Loss=0.4612
# Epoch23, Batch45: Loss=0.6236
# Epoch23, Batch46: Loss=0.4676
# Epoch23, Batch47: Loss=0.3039
# Epoch23, Batch48: Loss=0.3213
# Epoch23, Batch49: Loss=0.5540
# Epoch23, Batch50: Loss=0.3869
# Epoch23, Batch51: Loss=0.3378
# Epoch23, Batch52: Loss=0.3284
# Epoch23, Batch53: Loss=0.5582
# Epoch23, Batch54: Loss=0.4713
# Epoch23, Batch55: Loss=0.4843
# Epoch23, Batch56: Loss=0.6299
# Epoch23, Batch57: Loss=0.4843
# Epoch23, Batch58: Loss=0.3700
# Epoch23, Batch59: Loss=0.6024
# Epoch23, Batch60: Loss=0.4601
# Epoch23, Batch61: Loss=0.3049
# Epoch23, Batch62: Loss=0.6814
# Epoch23, Batch63: Loss=0.3316
# Epoch23, Batch64: Loss=0.3271
# Epoch23, Batch65: Loss=0.5641
# Epoch23, Batch66: Loss=0.2980
# Epoch23, Batch67: Loss=0.3056
# Epoch23, Batch68: Loss=0.4113
# Epoch23, Batch69: Loss=0.4466
# Epoch23, Batch70: Loss=0.4751
# Epoch23, Batch71: Loss=0.5536
# Epoch23, Batch72: Loss=0.3477
# Epoch23, Batch73: Loss=0.5633
# Epoch23, Batch74: Loss=0.5248
# Epoch23, Batch75: Loss=0.4164
# Epoch23, Batch76: Loss=0.3868
# Epoch23, Batch77: Loss=0.3299
# Epoch23, Batch78: Loss=0.4899
# Epoch23, Batch79: Loss=0.3491
# Epoch23, Batch80: Loss=0.6976
# Epoch23, Batch81: Loss=0.5211
# Epoch23, Batch82: Loss=0.5802
# Epoch23, Batch83: Loss=0.5643
# Epoch23, Batch84: Loss=0.3522
# Epoch23, Batch85: Loss=0.5966
# Epoch23, Batch86: Loss=0.5903
# Epoch23, Batch87: Loss=0.4080
# Epoch23, Batch88: Loss=0.5794
# Epoch23, Batch89: Loss=0.4814
# Epoch23, Batch90: Loss=0.3106
# Epoch23, Batch91: Loss=0.3991
# Epoch23, Batch92: Loss=0.3643
# Epoch23, Batch93: Loss=0.3020
# Epoch23, Batch94: Loss=0.3417
# Epoch23, Batch95: Loss=0.4515
# Epoch23, Batch96: Loss=0.3811
# Epoch23, Batch97: Loss=0.4600
# Epoch23, Batch98: Loss=0.5317
# Epoch23, Batch99: Loss=0.5345
# Epoch23, Batch100: Loss=0.5696
# Epoch23, Batch101: Loss=0.3776
# Epoch23, Batch102: Loss=0.4476
# Epoch23, Batch103: Loss=0.6021
# Epoch23, Batch104: Loss=0.6817
# Epoch23, Batch105: Loss=0.3578
# Epoch23, Batch106: Loss=0.3813
# Epoch23, Batch107: Loss=0.4102
# Epoch23, Batch108: Loss=0.3842
# Epoch23, Batch109: Loss=0.3468
# Epoch23, Batch110: Loss=0.3834
# Epoch23, Batch111: Loss=0.4717
# Epoch23, Batch112: Loss=0.4976
# Epoch23, Batch113: Loss=0.4491
# Epoch23, Batch114: Loss=0.5785
# Epoch23, Batch115: Loss=0.3524
# Epoch23, Batch116: Loss=0.4289
# Epoch23, Batch117: Loss=0.5142
# Epoch23, Batch118: Loss=0.5009
# Epoch23, Batch119: Loss=0.3872
# Epoch23, Batch120: Loss=0.3947
# Epoch23, Batch121: Loss=0.5789
# Epoch23, Batch122: Loss=0.4709
# Epoch23, Batch123: Loss=0.4194
# Epoch23, Batch124: Loss=0.3273
# Epoch23, Batch125: Loss=0.3536
# Epoch23, Batch126: Loss=0.3623
# Epoch23, Batch127: Loss=0.6100
# Epoch23, Batch128: Loss=0.2678
# Epoch23, Batch129: Loss=0.3626
# Epoch23, Batch130: Loss=0.2745
# Epoch23, Batch131: Loss=0.4347
# Epoch23, Batch132: Loss=0.5196
# Epoch23, Batch133: Loss=0.4964
# Epoch23, Batch134: Loss=0.6031
# Epoch23, Batch135: Loss=0.5007
# Epoch23, Batch136: Loss=0.2041
# Epoch23, Batch137: Loss=0.3497
# Epoch23, Batch138: Loss=0.4052
# Epoch23, Batch139: Loss=0.3317
# Epoch23, Batch140: Loss=0.5202
# Epoch23, Batch141: Loss=0.3287
# Epoch23, Batch142: Loss=0.5745
# Epoch23, Batch143: Loss=0.6707
# Epoch23, Batch144: Loss=0.3476
# Epoch23, Batch145: Loss=0.6808
# Epoch23, Batch146: Loss=0.3758
# Epoch23, Batch147: Loss=0.4824
# Epoch23, Batch148: Loss=0.4651
# Epoch23, Batch149: Loss=0.3560
# Epoch23, Batch150: Loss=0.5064
# Epoch23, Batch151: Loss=0.5187
# Epoch23, Batch152: Loss=0.4035
# Epoch23, Batch153: Loss=0.3734
# Epoch23, Batch154: Loss=0.3533
# Epoch23, Batch155: Loss=0.3678
# Epoch23, Batch156: Loss=0.1724
# Accuracy of pytorch_model set: 0.8425
# Epoch[24], Batch[100/60000], Loss:0.3789703845977783
# Epoch[24], Batch[200/60000], Loss:0.2966599464416504
# Epoch[24], Batch[300/60000], Loss:0.4598889648914337
# Epoch[24], Batch[400/60000], Loss:0.25945520401000977
# Epoch[24], Batch[500/60000], Loss:0.5961218476295471
# Epoch[24], Batch[600/60000], Loss:0.2202957719564438
# Epoch[24], Batch[700/60000], Loss:0.35955506563186646
# Epoch[24], Batch[800/60000], Loss:0.29814666509628296
# Epoch[24], Batch[900/60000], Loss:0.3283699154853821
# Accuracy of train set: 0.8635833333333334
# Epoch24, Batch0: Loss=0.4718
# Epoch24, Batch1: Loss=0.3221
# Epoch24, Batch2: Loss=0.6338
# Epoch24, Batch3: Loss=0.5137
# Epoch24, Batch4: Loss=0.4084
# Epoch24, Batch5: Loss=0.4395
# Epoch24, Batch6: Loss=0.4724
# Epoch24, Batch7: Loss=0.4766
# Epoch24, Batch8: Loss=0.5225
# Epoch24, Batch9: Loss=0.5075
# Epoch24, Batch10: Loss=0.5635
# Epoch24, Batch11: Loss=0.2803
# Epoch24, Batch12: Loss=0.4108
# Epoch24, Batch13: Loss=0.3679
# Epoch24, Batch14: Loss=0.3442
# Epoch24, Batch15: Loss=0.3269
# Epoch24, Batch16: Loss=0.4107
# Epoch24, Batch17: Loss=0.5295
# Epoch24, Batch18: Loss=0.3885
# Epoch24, Batch19: Loss=0.4069
# Epoch24, Batch20: Loss=0.2902
# Epoch24, Batch21: Loss=0.5322
# Epoch24, Batch22: Loss=0.3947
# Epoch24, Batch23: Loss=0.3960
# Epoch24, Batch24: Loss=0.4269
# Epoch24, Batch25: Loss=0.6502
# Epoch24, Batch26: Loss=0.4250
# Epoch24, Batch27: Loss=0.5527
# Epoch24, Batch28: Loss=0.4118
# Epoch24, Batch29: Loss=0.3737
# Epoch24, Batch30: Loss=0.3797
# Epoch24, Batch31: Loss=0.3346
# Epoch24, Batch32: Loss=0.3085
# Epoch24, Batch33: Loss=0.4278
# Epoch24, Batch34: Loss=0.4009
# Epoch24, Batch35: Loss=0.4605
# Epoch24, Batch36: Loss=0.6407
# Epoch24, Batch37: Loss=0.2955
# Epoch24, Batch38: Loss=0.4964
# Epoch24, Batch39: Loss=0.4876
# Epoch24, Batch40: Loss=0.3740
# Epoch24, Batch41: Loss=0.4289
# Epoch24, Batch42: Loss=0.3482
# Epoch24, Batch43: Loss=0.2647
# Epoch24, Batch44: Loss=0.5968
# Epoch24, Batch45: Loss=0.3150
# Epoch24, Batch46: Loss=0.3894
# Epoch24, Batch47: Loss=0.3842
# Epoch24, Batch48: Loss=0.3255
# Epoch24, Batch49: Loss=0.3345
# Epoch24, Batch50: Loss=0.2999
# Epoch24, Batch51: Loss=0.3967
# Epoch24, Batch52: Loss=0.4346
# Epoch24, Batch53: Loss=0.3144
# Epoch24, Batch54: Loss=0.3740
# Epoch24, Batch55: Loss=0.4280
# Epoch24, Batch56: Loss=0.3612
# Epoch24, Batch57: Loss=0.3642
# Epoch24, Batch58: Loss=0.3431
# Epoch24, Batch59: Loss=0.5550
# Epoch24, Batch60: Loss=0.5449
# Epoch24, Batch61: Loss=0.4926
# Epoch24, Batch62: Loss=0.3216
# Epoch24, Batch63: Loss=0.2763
# Epoch24, Batch64: Loss=0.4398
# Epoch24, Batch65: Loss=0.3873
# Epoch24, Batch66: Loss=0.3151
# Epoch24, Batch67: Loss=0.4980
# Epoch24, Batch68: Loss=0.3485
# Epoch24, Batch69: Loss=0.5470
# Epoch24, Batch70: Loss=0.5502
# Epoch24, Batch71: Loss=0.5311
# Epoch24, Batch72: Loss=0.3275
# Epoch24, Batch73: Loss=0.6621
# Epoch24, Batch74: Loss=0.3568
# Epoch24, Batch75: Loss=0.6025
# Epoch24, Batch76: Loss=0.4751
# Epoch24, Batch77: Loss=0.4081
# Epoch24, Batch78: Loss=0.4019
# Epoch24, Batch79: Loss=0.6325
# Epoch24, Batch80: Loss=0.4762
# Epoch24, Batch81: Loss=0.5902
# Epoch24, Batch82: Loss=0.4916
# Epoch24, Batch83: Loss=0.5295
# Epoch24, Batch84: Loss=0.3615
# Epoch24, Batch85: Loss=0.7887
# Epoch24, Batch86: Loss=0.3884
# Epoch24, Batch87: Loss=0.3510
# Epoch24, Batch88: Loss=0.5616
# Epoch24, Batch89: Loss=0.5394
# Epoch24, Batch90: Loss=0.5715
# Epoch24, Batch91: Loss=0.4598
# Epoch24, Batch92: Loss=0.5218
# Epoch24, Batch93: Loss=0.6856
# Epoch24, Batch94: Loss=0.3585
# Epoch24, Batch95: Loss=0.4336
# Epoch24, Batch96: Loss=0.5094
# Epoch24, Batch97: Loss=0.2288
# Epoch24, Batch98: Loss=0.4755
# Epoch24, Batch99: Loss=0.3388
# Epoch24, Batch100: Loss=0.7753
# Epoch24, Batch101: Loss=0.2257
# Epoch24, Batch102: Loss=0.5488
# Epoch24, Batch103: Loss=0.3390
# Epoch24, Batch104: Loss=0.4619
# Epoch24, Batch105: Loss=0.2447
# Epoch24, Batch106: Loss=0.3349
# Epoch24, Batch107: Loss=0.7432
# Epoch24, Batch108: Loss=0.3275
# Epoch24, Batch109: Loss=0.4794
# Epoch24, Batch110: Loss=0.4463
# Epoch24, Batch111: Loss=0.5320
# Epoch24, Batch112: Loss=0.3727
# Epoch24, Batch113: Loss=0.1951
# Epoch24, Batch114: Loss=0.4270
# Epoch24, Batch115: Loss=0.5654
# Epoch24, Batch116: Loss=0.3935
# Epoch24, Batch117: Loss=0.3900
# Epoch24, Batch118: Loss=0.4944
# Epoch24, Batch119: Loss=0.5210
# Epoch24, Batch120: Loss=0.2830
# Epoch24, Batch121: Loss=0.4650
# Epoch24, Batch122: Loss=0.4309
# Epoch24, Batch123: Loss=0.5107
# Epoch24, Batch124: Loss=0.4544
# Epoch24, Batch125: Loss=0.2641
# Epoch24, Batch126: Loss=0.5369
# Epoch24, Batch127: Loss=0.4313
# Epoch24, Batch128: Loss=0.3833
# Epoch24, Batch129: Loss=0.5913
# Epoch24, Batch130: Loss=0.3338
# Epoch24, Batch131: Loss=0.5561
# Epoch24, Batch132: Loss=0.2834
# Epoch24, Batch133: Loss=0.4642
# Epoch24, Batch134: Loss=0.5274
# Epoch24, Batch135: Loss=0.5764
# Epoch24, Batch136: Loss=0.3840
# Epoch24, Batch137: Loss=0.4232
# Epoch24, Batch138: Loss=0.2806
# Epoch24, Batch139: Loss=0.4425
# Epoch24, Batch140: Loss=0.3316
# Epoch24, Batch141: Loss=0.2903
# Epoch24, Batch142: Loss=0.3576
# Epoch24, Batch143: Loss=0.7701
# Epoch24, Batch144: Loss=0.2198
# Epoch24, Batch145: Loss=0.4193
# Epoch24, Batch146: Loss=0.3690
# Epoch24, Batch147: Loss=0.3447
# Epoch24, Batch148: Loss=0.5247
# Epoch24, Batch149: Loss=0.7687
# Epoch24, Batch150: Loss=0.4670
# Epoch24, Batch151: Loss=0.4225
# Epoch24, Batch152: Loss=0.4477
# Epoch24, Batch153: Loss=0.5348
# Epoch24, Batch154: Loss=0.3679
# Epoch24, Batch155: Loss=0.5061
# Epoch24, Batch156: Loss=0.5928
# Accuracy of pytorch_model set: 0.8452

# %%
print(f'Final test accuracy: {test_accuracies[-1]}')
# Out:
# Final test accuracy: 0.8452

# %% [markdown]
# ## Visualization of the labels and predictions
#
# In this section, you should visual one image from each class and show both the actual label and the predicted label for that image.

# %%
## FILL HERE

# %%
## FILL HERE
class_images = {}
for i in range(len(test_set)):
    image, label = test_set[i]
    out = model(image, parameters)
    _, pred = torch.max(out, 1)
    if label not in class_images:
        class_images[label] = (image, label, pred)
        print(int(pred), label)
    elif random.randint(0, 100) == 1:
        class_images[label] = (image, label, pred)

print(len(class_images))

fig, axs = plt.subplots(2, 5, figsize=(10, 4))
axs = axs.flatten()
for i in range(num_classes):
    axs[i].imshow(class_images[i][0][0])
    axs[i].set_title('true label: ' + FashionMNIST.classes[i] + ' predicted: ' + FashionMNIST.classes[int(class_images[i][2][0])], fontsize=6)
    axs[i].axis('off')
plt.show()
# Out:
# 9 9
# 2 2
# 1 1
# 6 6
# 4 4
# 5 5
# 7 7
# 3 3
# 8 8
# 0 0
# 10
